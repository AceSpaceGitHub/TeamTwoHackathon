# %% [markdown]
# 1. Import Dependencies

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env

# %% [markdown]
# # Building an Environment

# %% [markdown]
# Check Training Environment

# %%
import gym
from gym import Env
from gym.spaces import Discrete, Dict, MultiBinary, MultiDiscrete
import numpy as np
import random

class DeterministicScenario:
    def getActionSpace(self):
        return MultiDiscrete([6, 6, 2, 2])
    def getObservationSpace(self):
        return Dict({"missiles": Discrete(100), 
        "expectedShipDamage": MultiDiscrete([100,100,100,100,100,100]), 
        "currentShipDamage": MultiDiscrete([100,100,100,100,100,100]), 
        "target1Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target2Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target3Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target4Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target5Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target6Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target1Targets": MultiBinary(6),
        "target2Targets": MultiBinary(6),
        "target3Targets": MultiBinary(6),
        "target4Targets": MultiBinary(6),
        "target5Targets": MultiBinary(6),
        "target6Targets": MultiBinary(6),
        "assets": MultiDiscrete([100,100])})
    def getRandomizedState(self):
        return {"missiles": random.randint(1, 99),
         "expectedShipDamage": 
         np.array([random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4)]), 
         "currentShipDamage": np.array([0,0,0,0,0,0]),
         "target1Defense": np.array([0,0,25,0,15,0]),
         "target2Defense": np.array([0,0,0,25,0,15]),
         "target3Defense": np.array([0,0,30,0,0,0]),
         "target4Defense": np.array([0,0,0,30,0,0]),
         "target5Defense": np.array([0,0,0,0,40,0]),
         "target6Defense": np.array([0,0,0,0,0,40]),
         "target1Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target2Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target3Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target4Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target5Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "target6Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "assets": np.array([random.randint(1, 99), random.randint(1, 99)])}
    def getState(self, numberOfmissiles, numberOfJets, numberOfPilots, tD1, tD2, tD3, tD4, tD5, tD6):
        return {"missiles": numberOfmissiles,
         "expectedShipDamage": np.array([tD1, tD2, tD3, tD4, tD5, tD6]), 
         "currentShipDamage": np.array([0,0,0,0,0,0]),
         "target1Defense": np.array([0,0,25,0,15,0]),
         "target2Defense": np.array([0,0,0,25,0,15]),
         "target3Defense": np.array([0,0,30,0,0,0]),
         "target4Defense": np.array([0,0,0,30,0,0]),
         "target5Defense": np.array([0,0,0,0,40,0]),
         "target6Defense": np.array([0,0,0,0,0,40]),
         "target1Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target2Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target3Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target4Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target5Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "target6Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "assets": np.array([numberOfJets ,numberOfPilots])}
    def canAttack(self, state, sortiArray, ship1, ship2):
        canAttack = False
        reward = -10
        # Check if can attack
        for sorti in sortiArray:
            if state[sorti][ship1] and state[sorti][ship2]:
                canAttack = True
                reward = 20
                break
        return canAttack, reward
    def shouldAttack(self, state, defenseArray, ship):
        reward = 0
        shouldAttack = True
        # Check if ship is already more damaged than expected
        if state["currentShipDamage"][ship] >= state["expectedShipDamage"][ship]:
            # Check to see if target posses a threat
            if(state["currentShipDamage"][ship] == 0 and state[defenseArray[ship]][ship] > 0):
                # Reward for damaging a ship that is a threat?
                reward = 0
            else:
                # no threat and already at expected damage
                reward = -20
                shouldAttack = False
        else:
            # targetted a ship worth targetting
            reward = 100
        return shouldAttack, reward
    def defendShip(self, state, defenseArray, ship):
        shotDown = False
        length = len(state[defenseArray[ship]])
        for index in range(0, length):
            if(state[defenseArray[ship]][index] > 0):
                roll = random.randint(0,100)
                if(roll <= state[defenseArray[ship]][index]):
                    shotDown = True
        return shotDown
    def shootShip(self, state, defenseArray, ship):
        reward = 0

        state["currentShipDamage"][ship] += 1

        return reward
    def step(self, state, action):
        # Set placeholder for info
        info = {}
        reward = 0
        done = False
        numberOfTargets = 6
        defenseArray = ["target1Defense", "target2Defense", "target3Defense", "target4Defense", "target5Defense", "target6Defense"]
        sortieArray = ["target1Targets", "target2Targets", "target3Targets", "target4Targets", "target5Targets", "target6Targets"]

        # Should we reward here or after hit or even after checking against expected damage?
        ship1Index = action[0]
        ship2Index = action[1]

        if action[2] == 1:
            reward += 10
        if action[3] == 1:
            reward += 10

        canAttack , canAttackReward = self.canAttack(state, sortieArray, ship1Index, ship2Index)
        reward += canAttackReward
        if canAttack:

            shotDown1 = self.defendShip(state, defenseArray, ship1Index)
            shotDown2 = self.defendShip(state, defenseArray, ship2Index)

            if ship1Index == ship2Index:
                if shotDown1:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1
            else:
                if shotDown1:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1
                if shotDown2:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1

            shouldAttack, shouldAttackReward = self.shouldAttack(state, defenseArray, ship1Index)
            reward += shouldAttackReward
            self.shootShip(state, defenseArray, ship1Index)
            state["missiles"] -= 1
            if action[2] == 1:
                shouldAttack, shouldAttackReward = self.shouldAttack(state, defenseArray, ship1Index)
                reward += shouldAttackReward
                self.shootShip(state, defenseArray, ship1Index)
                state["missiles"] -= 1
            shouldAttack, shouldAttackReward = self.shouldAttack(state, defenseArray, ship2Index)
            reward += shouldAttackReward
            self.shootShip(state, defenseArray, ship2Index)
            state["missiles"] -= 1
            if action[3] == 1:
                shouldAttack, shouldAttackReward = self.shouldAttack(state, defenseArray, ship2Index)
                reward += shouldAttackReward
                self.shootShip(state, defenseArray, ship2Index)
                state["missiles"] -= 1
        else:
            # Can't attack we are done
            return state, canAttackReward, False, info
        
        # ############# Ideas #################
        # Count up assets instead of down. Add a cap and remove end condition for assets
        # Change Reward/Loss system for expected damage.
        #   Expected damage is now Expected hits. Remove Rolls
        # Add a calculated ratio reward for threats in the defending arrays
        # Add in standard deviation for rewards to encourage spreading out more hits when missles are available.
        #   Prio higher expected hits targets.

        # Add penalty for going over on assets
        if state["missiles"] < 0:
            reward -= 200

        if state ["assets"][0] < 0:
            reward -= 200

        if state ["assets"][1] < 0:
            reward -= 200

        isExpectedDamageMet = True
        for shipIndex in range(0, numberOfTargets):
            if state["currentShipDamage"][shipIndex] < state["expectedShipDamage"][shipIndex]:
                isExpectedDamageMet = False
                break

        if isExpectedDamageMet:
            reward += 100
            reward += max(0, state["missiles"])*10
            reward += max(0, state["assets"][0])*5
            reward += max(0, state["assets"][1])*5
            done = True

        if state["missiles"] <= 0:
            done = True

        if state["assets"][0] <= 0 or state["assets"][1] <= 0:
            done = True
        
        # Return step information
        return state, reward, done, info

class DeterministicScenarioEnvironment(Env):
    def __init__(self, numberOfmissiles, numberOfJets, numberOfPilots, tD1, tD2, tD3, tD4, tD5, tD6):
        manager = DeterministicScenario()
        self.manager = manager
        # Actions we can take: 0 - Do Nothing, 1 - Launch
        self.action_space = manager.getActionSpace()
        # Target Damage state array: 0 - Untouched, 1 - Disabled, 2 - Destroyed
        self.observation_space = manager.getObservationSpace()
        # store initial state
        self.numberOfmissiles = numberOfmissiles
        self.numberOfJets = numberOfJets
        self.numberOfPilots = numberOfPilots
        self.tD1 = tD1
        self.tD2 = tD2
        self.tD3 = tD3
        self.tD4 = tD4
        self.tD5 = tD5
        self.tD6 = tD6
        # Set start state
        self.state = self.manager.getState(self.numberOfmissiles, self.numberOfJets, self.numberOfPilots, self.tD1, self.tD2, self.tD3, self.tD4, self.tD5, self.tD6)

    def step(self, action):
        # Return step information
        return self.manager.step(self.state, action)

    def render(self):
        # Implement viz
        pass

    def reset(self):
        # Reset shower temperature
        self.state = self.manager.getState(self.numberOfmissiles, self.numberOfJets, self.numberOfPilots, self.tD1, self.tD2, self.tD3, self.tD4, self.tD5, self.tD6)
        return self.state

class TrainingDeterministicScenarioEnvironment(Env):
    def __init__(self):
        manager = DeterministicScenario()
        self.manager = manager
        # Actions we can take: 0 - Do Nothing, 1 - Launch
        self.action_space = manager.getActionSpace()
        # Target Damage state array: 0 - Untouched, 1 - Disabled, 2 - Destroyed
        self.observation_space = manager.getObservationSpace()
        # Set start state
        self.state = manager.getRandomizedState()

    def step(self, action):
        # Return step information
        return self.manager.step(self.state, action)

    def render(self):
        # Implement viz
        pass

    def reset(self):
        # Reset shower temperature
        self.state = self.manager.getRandomizedState()
        return self.state

# %%
trainingEnv=TrainingDeterministicScenarioEnvironment()
check_env(trainingEnv, warn=True)

# %% [markdown]
# Check Scenario Environment

# %% [markdown]
# # Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
#trainingEnv=TrainingDeterministicScenarioEnvironment()
trainingEnv=TrainingDeterministicScenarioEnvironment()
check_env(trainingEnv, warn=True)
trainingEnv.reset()
model = PPO("MultiInputPolicy", trainingEnv, verbose=1, tensorboard_log=log_path)

# 30ish minute training
#model.learn(total_timesteps=300000*5)

model.learn(total_timesteps=700000*2)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_72
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 1.1e+03  |
# | time/              |          |
# |    fps             | 465      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.5         |
# |    ep_rew_mean          | 1.17e+03     |
# | time/                   |              |
# |    fps                  | 373          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0010401157 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 5.79e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.65e+04     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 2.39e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.4         |
# |    ep_rew_mean          | 1.12e+03     |
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0032559107 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 1.07e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.87e+05     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00296     |
# |    value_loss           | 3.17e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.3         |
# |    ep_rew_mean          | 1.13e+03     |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0035763376 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 6.56e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+05     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 2.44e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.8         |
# |    ep_rew_mean          | 993          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 5            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0062000155 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.65e+05     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00526     |
# |    value_loss           | 2.72e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.8         |
# |    ep_rew_mean          | 1.09e+03     |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 6            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0040389784 |
# |    clip_fraction        | 0.00869      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.31e+04     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00405     |
# |    value_loss           | 2.07e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.4         |
# |    ep_rew_mean          | 1.08e+03     |
# | time/                   |              |
# |    fps                  | 325          |
# |    iterations           | 7            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0057611545 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+05     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00515     |
# |    value_loss           | 2.57e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.2         |
# |    ep_rew_mean          | 1.08e+03     |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 8            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0035917307 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.03e+05     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 2.39e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.4        |
# |    ep_rew_mean          | 1.15e+03    |
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 9           |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004602573 |
# |    clip_fraction        | 0.0041      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.93e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00312    |
# |    value_loss           | 2.44e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.9         |
# |    ep_rew_mean          | 1.06e+03     |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 10           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0020994102 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67e+05     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 2.51e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.4         |
# |    ep_rew_mean          | 1.22e+03     |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 11           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0032708484 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32e+05     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00361     |
# |    value_loss           | 2.54e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.4         |
# |    ep_rew_mean          | 1.07e+03     |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 12           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0029104664 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.29e+05     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 2.7e+05      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.9        |
# |    ep_rew_mean          | 1.2e+03     |
# | time/                   |             |
# |    fps                  | 318         |
# |    iterations           | 13          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.004777926 |
# |    clip_fraction        | 0.0063      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33e+05    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0041     |
# |    value_loss           | 2.82e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.4         |
# |    ep_rew_mean          | 1.18e+03     |
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 14           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0041805794 |
# |    clip_fraction        | 0.00303      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+05     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 2.55e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.5        |
# |    ep_rew_mean          | 1.1e+03     |
# | time/                   |             |
# |    fps                  | 317         |
# |    iterations           | 15          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010572802 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.94       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.17e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00584    |
# |    value_loss           | 2.28e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.9         |
# |    ep_rew_mean          | 1.11e+03     |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 16           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0073747216 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.91        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.59e+05     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00639     |
# |    value_loss           | 2.27e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.8       |
# |    ep_rew_mean          | 1.17e+03   |
# | time/                   |            |
# |    fps                  | 317        |
# |    iterations           | 17         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00889823 |
# |    clip_fraction        | 0.037      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.89      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.32e+04   |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0058    |
# |    value_loss           | 2.36e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.9        |
# |    ep_rew_mean          | 1.1e+03     |
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 18          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006470109 |
# |    clip_fraction        | 0.0205      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.9        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16e+05    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0055     |
# |    value_loss           | 2.54e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.8         |
# |    ep_rew_mean          | 1.13e+03     |
# | time/                   |              |
# |    fps                  | 316          |
# |    iterations           | 19           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0070816022 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.88        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+05     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0061      |
# |    value_loss           | 2.29e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.2        |
# |    ep_rew_mean          | 1.17e+03    |
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 20          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006550724 |
# |    clip_fraction        | 0.0435      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.85       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17e+05    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 2.89e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.5        |
# |    ep_rew_mean          | 1.23e+03    |
# | time/                   |             |
# |    fps                  | 315         |
# |    iterations           | 21          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005006346 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.87       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.61e+05    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00451    |
# |    value_loss           | 3.03e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.3       |
# |    ep_rew_mean          | 1.21e+03   |
# | time/                   |            |
# |    fps                  | 315        |
# |    iterations           | 22         |
# |    time_elapsed         | 142        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00565984 |
# |    clip_fraction        | 0.0224     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.87      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.24e+05   |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00548   |
# |    value_loss           | 2.69e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27           |
# |    ep_rew_mean          | 1.07e+03     |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 23           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0050658667 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+05      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 2.77e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29          |
# |    ep_rew_mean          | 1.04e+03    |
# | time/                   |             |
# |    fps                  | 315         |
# |    iterations           | 24          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007720551 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.84       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.55e+04    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0081     |
# |    value_loss           | 2.04e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.5        |
# |    ep_rew_mean          | 1.24e+03    |
# | time/                   |             |
# |    fps                  | 315         |
# |    iterations           | 25          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006418366 |
# |    clip_fraction        | 0.0199      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.81       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.63e+04    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 1.97e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.9         |
# |    ep_rew_mean          | 1.1e+03      |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 26           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0068875444 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.78        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32e+05     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00677     |
# |    value_loss           | 2.63e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.6         |
# |    ep_rew_mean          | 1.14e+03     |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 27           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0056733466 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.76        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35e+05     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00531     |
# |    value_loss           | 2.26e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.1        |
# |    ep_rew_mean          | 1.24e+03    |
# | time/                   |             |
# |    fps                  | 314         |
# |    iterations           | 28          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.006822055 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.73       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83e+05    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.006      |
# |    value_loss           | 2.44e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.6       |
# |    ep_rew_mean          | 1.19e+03   |
# | time/                   |            |
# |    fps                  | 315        |
# |    iterations           | 29         |
# |    time_elapsed         | 188        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.00714559 |
# |    clip_fraction        | 0.0369     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.73      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.4e+05    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.00598   |
# |    value_loss           | 2.39e+05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.1       |
# |    ep_rew_mean          | 1.09e+03   |
# | time/                   |            |
# |    fps                  | 315        |
# |    iterations           | 30         |
# |    time_elapsed         | 194        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00924902 |
# |    clip_fraction        | 0.0477     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.72      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.62e+04   |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00926   |
# |    value_loss           | 2e+05      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.8         |
# |    ep_rew_mean          | 1.03e+03     |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 31           |
# |    time_elapsed         | 201          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0074924314 |
# |    clip_fraction        | 0.0565       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.69        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.44e+04     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00659     |
# |    value_loss           | 2.15e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.4         |
# |    ep_rew_mean          | 1.11e+03     |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 32           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0069255875 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.7         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.47e+04     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00784     |
# |    value_loss           | 1.77e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.3       |
# |    ep_rew_mean          | 1.2e+03    |
# | time/                   |            |
# |    fps                  | 314        |
# |    iterations           | 33         |
# |    time_elapsed         | 214        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00444314 |
# |    clip_fraction        | 0.00864    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.69      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.26e+05   |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00306   |
# |    value_loss           | 2.41e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.7         |
# |    ep_rew_mean          | 1.12e+03     |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 34           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0065702447 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.66        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+05     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00607     |
# |    value_loss           | 2.33e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.1        |
# |    ep_rew_mean          | 950         |
# | time/                   |             |
# |    fps                  | 315         |
# |    iterations           | 35          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004409535 |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.7        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1e+05       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 2.14e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.2        |
# |    ep_rew_mean          | 946         |
# | time/                   |             |
# |    fps                  | 314         |
# |    iterations           | 36          |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.115984455 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.67       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.82e+04    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0286      |
# |    value_loss           | 1.54e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.5         |
# |    ep_rew_mean          | 1.09e+03     |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 37           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0074968953 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.41        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.21e+04     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00591     |
# |    value_loss           | 2.08e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.7         |
# |    ep_rew_mean          | 1.2e+03      |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 38           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0067573683 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.41        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06e+05     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00466     |
# |    value_loss           | 2.24e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.2         |
# |    ep_rew_mean          | 1.19e+03     |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 39           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0053801695 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06e+05     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00368     |
# |    value_loss           | 2.37e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.5         |
# |    ep_rew_mean          | 1.12e+03     |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 40           |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0051433016 |
# |    clip_fraction        | 0.0264       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+05     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00516     |
# |    value_loss           | 2.18e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25           |
# |    ep_rew_mean          | 1.14e+03     |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 41           |
# |    time_elapsed         | 267          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0058546313 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.38        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.05e+05     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00527     |
# |    value_loss           | 2.39e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.8        |
# |    ep_rew_mean          | 1.08e+03    |
# | time/                   |             |
# |    fps                  | 314         |
# |    iterations           | 42          |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008752728 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07e+05    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00787    |
# |    value_loss           | 2.14e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.1         |
# |    ep_rew_mean          | 1.22e+03     |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 43           |
# |    time_elapsed         | 280          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0070244996 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.34        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.29e+05     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00663     |
# |    value_loss           | 2.63e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.6        |
# |    ep_rew_mean          | 1.26e+03    |
# | time/                   |             |
# |    fps                  | 314         |
# |    iterations           | 44          |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008317799 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36e+05    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00686    |
# |    value_loss           | 2.67e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.2        |
# |    ep_rew_mean          | 1.28e+03    |
# | time/                   |             |
# |    fps                  | 314         |
# |    iterations           | 45          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.006383285 |
# |    clip_fraction        | 0.0324      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.57e+04    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00568    |
# |    value_loss           | 2.09e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.7         |
# |    ep_rew_mean          | 1.13e+03     |
# | time/                   |              |
# |    fps                  | 313          |
# |    iterations           | 46           |
# |    time_elapsed         | 300          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0069197603 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.34        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+05     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00689     |
# |    value_loss           | 2.41e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.9         |
# |    ep_rew_mean          | 1.2e+03      |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 47           |
# |    time_elapsed         | 306          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0067993915 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37e+05     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00567     |
# |    value_loss           | 2.79e+05     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25.2      |
# |    ep_rew_mean          | 1.14e+03  |
# | time/                   |           |
# |    fps                  | 314       |
# |    iterations           | 48        |
# |    time_elapsed         | 313       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.0050325 |
# |    clip_fraction        | 0.0324    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.35     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.05e+05  |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -0.00492  |
# |    value_loss           | 2.31e+05  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.9         |
# |    ep_rew_mean          | 1.2e+03      |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 49           |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0077908346 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.35        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02e+05     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00676     |
# |    value_loss           | 2.42e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.8         |
# |    ep_rew_mean          | 1.25e+03     |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 50           |
# |    time_elapsed         | 326          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0064905845 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.35        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.38e+05     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00717     |
# |    value_loss           | 2.67e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.8        |
# |    ep_rew_mean          | 1.25e+03    |
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 51          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.006553317 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.61e+05    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00493    |
# |    value_loss           | 2.98e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.8        |
# |    ep_rew_mean          | 1.13e+03    |
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 52          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009504662 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+05    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 2.02e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.8        |
# |    ep_rew_mean          | 1.2e+03     |
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 53          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.006387772 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.36e+04    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00524    |
# |    value_loss           | 2.1e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26           |
# |    ep_rew_mean          | 1.16e+03     |
# | time/                   |              |
# |    fps                  | 313          |
# |    iterations           | 54           |
# |    time_elapsed         | 352          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0075259595 |
# |    clip_fraction        | 0.0519       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.31        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.38e+04     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0082      |
# |    value_loss           | 2.44e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.9        |
# |    ep_rew_mean          | 1.12e+03    |
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 55          |
# ...
# |    iterations           | 667          |
# |    time_elapsed         | 4665         |
# |    total_timesteps      | 1366016      |
# | train/                  |              |
# |    approx_kl            | 0.0030072192 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.444       |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.36e+03     |
# |    n_updates            | 6660         |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 7.66e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.03        |
# |    ep_rew_mean          | 1.92e+03    |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 668         |
# |    time_elapsed         | 4672        |
# |    total_timesteps      | 1368064     |
# | train/                  |             |
# |    approx_kl            | 0.001985319 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.456      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.36e+03    |
# |    n_updates            | 6670        |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 9.49e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.14         |
# |    ep_rew_mean          | 1.9e+03      |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 669          |
# |    time_elapsed         | 4680         |
# |    total_timesteps      | 1370112      |
# | train/                  |              |
# |    approx_kl            | 0.0047357427 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.436       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.47e+03     |
# |    n_updates            | 6680         |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 7.39e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.67         |
# |    ep_rew_mean          | 1.82e+03     |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 670          |
# |    time_elapsed         | 4687         |
# |    total_timesteps      | 1372160      |
# | train/                  |              |
# |    approx_kl            | 0.0021331094 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.457       |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 716          |
# |    n_updates            | 6690         |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 6.83e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.98         |
# |    ep_rew_mean          | 1.84e+03     |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 671          |
# |    time_elapsed         | 4695         |
# |    total_timesteps      | 1374208      |
# | train/                  |              |
# |    approx_kl            | 0.0005494291 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.458       |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.51e+03     |
# |    n_updates            | 6700         |
# |    policy_gradient_loss | -0.000453    |
# |    value_loss           | 2e+04        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.08         |
# |    ep_rew_mean          | 1.88e+03     |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 672          |
# |    time_elapsed         | 4703         |
# |    total_timesteps      | 1376256      |
# | train/                  |              |
# |    approx_kl            | 0.0013181292 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.19e+03     |
# |    n_updates            | 6710         |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 9.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.14         |
# |    ep_rew_mean          | 1.9e+03      |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 673          |
# |    time_elapsed         | 4710         |
# |    total_timesteps      | 1378304      |
# | train/                  |              |
# |    approx_kl            | 0.0012030139 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.451       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 668          |
# |    n_updates            | 6720         |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 7.02e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.9          |
# |    ep_rew_mean          | 1.92e+03     |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 674          |
# |    time_elapsed         | 4718         |
# |    total_timesteps      | 1380352      |
# | train/                  |              |
# |    approx_kl            | 0.0007147578 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.447       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.54e+03     |
# |    n_updates            | 6730         |
# |    policy_gradient_loss | -0.000675    |
# |    value_loss           | 6.18e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.99         |
# |    ep_rew_mean          | 1.87e+03     |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 675          |
# |    time_elapsed         | 4725         |
# |    total_timesteps      | 1382400      |
# | train/                  |              |
# |    approx_kl            | 0.0018229545 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.439       |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.62e+03     |
# |    n_updates            | 6740         |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 1.06e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.76         |
# |    ep_rew_mean          | 1.82e+03     |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 676          |
# |    time_elapsed         | 4733         |
# |    total_timesteps      | 1384448      |
# | train/                  |              |
# |    approx_kl            | 0.0014782075 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.455       |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02e+03     |
# |    n_updates            | 6750         |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 7.24e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5.34          |
# |    ep_rew_mean          | 1.94e+03      |
# | time/                   |               |
# |    fps                  | 292           |
# |    iterations           | 677           |
# |    time_elapsed         | 4741          |
# |    total_timesteps      | 1386496       |
# | train/                  |               |
# |    approx_kl            | 0.00092777406 |
# |    clip_fraction        | 0.0122        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.434        |
# |    explained_variance   | 0.97          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.31e+03      |
# |    n_updates            | 6760          |
# |    policy_gradient_loss | -0.00133      |
# |    value_loss           | 5.52e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.92         |
# |    ep_rew_mean          | 2e+03        |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 678          |
# |    time_elapsed         | 4748         |
# |    total_timesteps      | 1388544      |
# | train/                  |              |
# |    approx_kl            | 0.0032117395 |
# |    clip_fraction        | 0.0517       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.458       |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.15e+03     |
# |    n_updates            | 6770         |
# |    policy_gradient_loss | -0.00449     |
# |    value_loss           | 8.73e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.98         |
# |    ep_rew_mean          | 1.9e+03      |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 679          |
# |    time_elapsed         | 4756         |
# |    total_timesteps      | 1390592      |
# | train/                  |              |
# |    approx_kl            | 0.0023033507 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.416       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.69e+03     |
# |    n_updates            | 6780         |
# |    policy_gradient_loss | -0.000959    |
# |    value_loss           | 1.01e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.19         |
# |    ep_rew_mean          | 1.93e+03     |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 680          |
# |    time_elapsed         | 4764         |
# |    total_timesteps      | 1392640      |
# | train/                  |              |
# |    approx_kl            | 0.0009038796 |
# |    clip_fraction        | 0.00977      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.445       |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04e+03     |
# |    n_updates            | 6790         |
# |    policy_gradient_loss | -0.000652    |
# |    value_loss           | 8.9e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.75         |
# |    ep_rew_mean          | 1.91e+03     |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 681          |
# |    time_elapsed         | 4771         |
# |    total_timesteps      | 1394688      |
# | train/                  |              |
# |    approx_kl            | 0.0016723112 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.433       |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.53e+03     |
# |    n_updates            | 6800         |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 4.59e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.1          |
# |    ep_rew_mean          | 1.91e+03     |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 682          |
# |    time_elapsed         | 4779         |
# |    total_timesteps      | 1396736      |
# | train/                  |              |
# |    approx_kl            | 0.0031011812 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.418       |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.49e+03     |
# |    n_updates            | 6810         |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 1.36e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.87         |
# |    ep_rew_mean          | 1.81e+03     |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 683          |
# |    time_elapsed         | 4787         |
# |    total_timesteps      | 1398784      |
# | train/                  |              |
# |    approx_kl            | 0.0012822029 |
# |    clip_fraction        | 0.00771      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.465       |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 959          |
# |    n_updates            | 6820         |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 1.29e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.25         |
# |    ep_rew_mean          | 1.94e+03     |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 684          |
# |    time_elapsed         | 4795         |
# |    total_timesteps      | 1400832      |
# | train/                  |              |
# |    approx_kl            | 0.0009667363 |
# |    clip_fraction        | 0.00977      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.432       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.8e+03      |
# |    n_updates            | 6830         |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 6.41e+03     |
# ------------------------------------------

# %% [markdown]
# # Save Model

# %%
model.save('DeterministicTraining1')

# %% [markdown]
# # Evaluate Model

# %%
scenarioEnv.reset()
evaluate_policy(model, scenarioEnv, n_eval_episodes=10000, render=False)

# %%
scenarioEnv = DeterministicScenarioEnvironment(28, 19, 21, 0, 0, 0, 0, 6, 0)
sampleEnvObs = scenarioEnv.reset()
done = False
score = 0 

while not done:
    action, _ = model.predict(sampleEnvObs)
    sampleEnvObs, reward, done, info = scenarioEnv.step(action)
    score+=reward
    print('Score:{} Action:{} State:{}'.format(score, action, [sampleEnvObs["missiles"],sampleEnvObs["expectedShipDamage"], sampleEnvObs["currentShipDamage"], sampleEnvObs["assets"]]))
scenarioEnv.close()
# Out:
# Score:220 Action:[5 4 1 1] State:[24, array([0, 0, 0, 0, 6, 0]), array([0, 0, 0, 0, 2, 2]), array([18, 20])]
# Score:200 Action:[3 1 1 1] State:[20, array([0, 0, 0, 0, 6, 0]), array([0, 2, 0, 2, 2, 2]), array([16, 18])]
# Score:180 Action:[0 2 1 1] State:[16, array([0, 0, 0, 0, 6, 0]), array([2, 2, 2, 2, 2, 2]), array([15, 17])]
# Score:380 Action:[5 4 1 1] State:[12, array([0, 0, 0, 0, 6, 0]), array([2, 2, 2, 2, 4, 4]), array([14, 16])]
# Score:370 Action:[3 2 1 1] State:[12, array([0, 0, 0, 0, 6, 0]), array([2, 2, 2, 2, 4, 4]), array([14, 16])]
# Score:330 Action:[0 2 1 1] State:[8, array([0, 0, 0, 0, 6, 0]), array([4, 2, 4, 2, 4, 4]), array([12, 14])]
# Score:290 Action:[3 1 1 1] State:[4, array([0, 0, 0, 0, 6, 0]), array([4, 4, 4, 4, 4, 4]), array([11, 13])]
# Score:700 Action:[5 4 1 1] State:[0, array([0, 0, 0, 0, 6, 0]), array([4, 4, 4, 4, 6, 6]), array([10, 12])]
