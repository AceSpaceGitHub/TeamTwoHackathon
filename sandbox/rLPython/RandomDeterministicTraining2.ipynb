# %% [markdown]
# 1. Import Dependencies

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env

# %% [markdown]
# # Building an Environment

# %% [markdown]
# Check Training Environment

# %%
import gym
from gym import Env
from gym.spaces import Discrete, Dict, MultiBinary, MultiDiscrete
import numpy as np
import random

class DeterministicScenario:
    def getActionSpace(self):
        return MultiDiscrete([6, 6, 2, 2])
    def getObservationSpace(self):
        return Dict({"missiles": Discrete(100), 
        "expectedShipDamage": MultiDiscrete([100,100,100,100,100,100]), 
        "currentShipDamage": MultiDiscrete([100,100,100,100,100,100]), 
        "target1Targets": MultiBinary(6),
        "target2Targets": MultiBinary(6),
        "target3Targets": MultiBinary(6),
        "target4Targets": MultiBinary(6),
        "target5Targets": MultiBinary(6),
        "target6Targets": MultiBinary(6),
        "assets": MultiDiscrete([100,100])})
    def getRandomizedState(self):
        return {"missiles": random.randint(1, 99),
         "expectedShipDamage": 
         np.array([random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4)]), 
         "currentShipDamage": np.array([0,0,0,0,0,0]),
         "target1Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target2Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target3Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target4Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target5Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "target6Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "assets": np.array([random.randint(1, 99), random.randint(1, 99)])}
    def getState(self, numberOfmissiles, numberOfJets, numberOfPilots, tD1, tD2, tD3, tD4, tD5, tD6):
        return {"missiles": numberOfmissiles,
         "expectedShipDamage": np.array([tD1, tD2, tD3, tD4, tD5, tD6]), 
         "currentShipDamage": np.array([0,0,0,0,0,0]),
         "target1Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target2Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target3Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target4Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target5Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "target6Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "assets": np.array([numberOfJets ,numberOfPilots])}
    def canAttack(self, state, sortiArray, ship1, ship2):
        canAttack = False
        reward = -20
        # Check if can attack
        for sorti in sortiArray:
            if state[sorti][ship1] and state[sorti][ship2]:
                canAttack = True
                break
        return canAttack, reward
    def shouldAttack(self, state, ship):
        reward = 0
        # Check if ship is already more damaged than expected
        if state["currentShipDamage"][ship] >= state["expectedShipDamage"][ship]:
            # Check to see if target posses a threat
                # no threat and already at expected damage
            reward = -20
        else:
            # targetted a ship worth targetting
            reward = 40
        return reward
    def defendShip(self, state, ship):
        shotDown = False
        return shotDown
    def shootShip(self, state, ship):
        reward = 0

        state["currentShipDamage"][ship] += 1

        return reward
    def step(self, state, action):
        # Set placeholder for info
        info = {}
        reward = 0
        done = False
        numberOfTargets = 6
        sortieArray = ["target1Targets", "target2Targets", "target3Targets", "target4Targets", "target5Targets", "target6Targets"]

        # Should we reward here or after hit or even after checking against expected damage?
        ship1Index = action[0]
        ship2Index = action[1]

        if action[2] == 1:
            reward += 10
        if action[3] == 1:
            reward += 10

        canAttack , canAttackReward = self.canAttack(state, sortieArray, ship1Index, ship2Index)
        reward += canAttackReward
        if canAttack:

            shotDown1 = self.defendShip(state, ship1Index)
            shotDown2 = self.defendShip(state, ship2Index)

            if ship1Index == ship2Index:
                if shotDown1:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1
            else:
                if shotDown1:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1
                if shotDown2:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1

            shouldAttackReward = self.shouldAttack(state, ship1Index)
            reward += shouldAttackReward
            self.shootShip(state, ship1Index)
            state["missiles"] -= 1
            if action[2] == 1:
                shouldAttackReward = self.shouldAttack(state, ship1Index)
                reward += shouldAttackReward
                self.shootShip(state, ship1Index)
                state["missiles"] -= 1
            shouldAttackReward = self.shouldAttack(state, ship2Index)
            reward += shouldAttackReward
            self.shootShip(state, ship2Index)
            state["missiles"] -= 1
            if action[3] == 1:
                shouldAttackReward = self.shouldAttack(state, ship2Index)
                reward += shouldAttackReward
                self.shootShip(state, ship2Index)
                state["missiles"] -= 1
        else:
            # Can't attack we are done
            return state, canAttackReward, False, info
        
        # ############# Ideas #################
        # Count up assets instead of down. Add a cap and remove end condition for assets
        # Change Reward/Loss system for expected damage.
        #   Expected damage is now Expected hits. Remove Rolls
        # Add a calculated ratio reward for threats in the defending arrays
        # Add in standard deviation for rewards to encourage spreading out more hits when missles are available.
        #   Prio higher expected hits targets.

        # Add penalty for going over on assets
        if state["missiles"] < 0:
            reward = -500

        if state ["assets"][0] < 0:
            reward = -500

        if state ["assets"][1] < 0:
            reward = -500

        isExpectedDamageMet = True
        for shipIndex in range(0, numberOfTargets):
            if state["currentShipDamage"][shipIndex] < state["expectedShipDamage"][shipIndex]:
                isExpectedDamageMet = False
                break

        if isExpectedDamageMet:
            reward += 100
            reward += max(0, state["missiles"])*10
            reward += max(0, state["assets"][0])*5
            reward += max(0, state["assets"][1])*5
            done = True

        if state["missiles"] <= 0:
            done = True

        if state["assets"][0] <= 0 or state["assets"][1] <= 0:
            done = True
        
        # Return step information
        return state, reward, done, info

class DeterministicScenarioEnvironment(Env):
    def __init__(self, numberOfmissiles, numberOfJets, numberOfPilots, tD1, tD2, tD3, tD4, tD5, tD6):
        manager = DeterministicScenario()
        self.manager = manager
        # Actions we can take: 0 - Do Nothing, 1 - Launch
        self.action_space = manager.getActionSpace()
        # Target Damage state array: 0 - Untouched, 1 - Disabled, 2 - Destroyed
        self.observation_space = manager.getObservationSpace()
        # store initial state
        self.numberOfmissiles = numberOfmissiles
        self.numberOfJets = numberOfJets
        self.numberOfPilots = numberOfPilots
        self.tD1 = tD1
        self.tD2 = tD2
        self.tD3 = tD3
        self.tD4 = tD4
        self.tD5 = tD5
        self.tD6 = tD6
        # Set start state
        self.state = self.manager.getState(self.numberOfmissiles, self.numberOfJets, self.numberOfPilots, self.tD1, self.tD2, self.tD3, self.tD4, self.tD5, self.tD6)

    def step(self, action):
        # Return step information
        return self.manager.step(self.state, action)

    def render(self):
        # Implement viz
        pass

    def reset(self):
        # Reset shower temperature
        self.state = self.manager.getState(self.numberOfmissiles, self.numberOfJets, self.numberOfPilots, self.tD1, self.tD2, self.tD3, self.tD4, self.tD5, self.tD6)
        return self.state

class TrainingDeterministicScenarioEnvironment(Env):
    def __init__(self):
        manager = DeterministicScenario()
        self.manager = manager
        # Actions we can take: 0 - Do Nothing, 1 - Launch
        self.action_space = manager.getActionSpace()
        # Target Damage state array: 0 - Untouched, 1 - Disabled, 2 - Destroyed
        self.observation_space = manager.getObservationSpace()
        # Set start state
        self.state = manager.getRandomizedState()

    def step(self, action):
        # Return step information
        return self.manager.step(self.state, action)

    def render(self):
        # Implement viz
        pass

    def reset(self):
        # Reset shower temperature
        self.state = self.manager.getRandomizedState()
        return self.state

# %%
trainingEnv=TrainingDeterministicScenarioEnvironment()
check_env(trainingEnv, warn=True)

# %% [markdown]
# Check Scenario Environment

# %% [markdown]
# # Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
#trainingEnv=TrainingDeterministicScenarioEnvironment()
trainingEnv=TrainingDeterministicScenarioEnvironment()
check_env(trainingEnv, warn=True)
trainingEnv.reset()
model = PPO("MultiInputPolicy", trainingEnv, verbose=1, tensorboard_log=log_path)

# 30ish minute training
#model.learn(total_timesteps=300000*5)

model.learn(total_timesteps=150000*2*4)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_87
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.3     |
# |    ep_rew_mean     | -209     |
# | time/              |          |
# |    fps             | 593      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.4        |
# |    ep_rew_mean          | -117        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006606901 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 6.89e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1e+05       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 1.76e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.8         |
# |    ep_rew_mean          | 3.55         |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0007595618 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 0.0106       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.39e+04     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 1.5e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.2         |
# |    ep_rew_mean          | -83.6        |
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 4            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0023608059 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 0.0131       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.85e+04     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 1.46e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31           |
# |    ep_rew_mean          | 31.6         |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 5            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0007767073 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 0.0166       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.52e+04     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 1.64e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.2         |
# |    ep_rew_mean          | -43.5        |
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 6            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0007748477 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 0.00265      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.53e+04     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00185     |
# |    value_loss           | 1.66e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.9        |
# |    ep_rew_mean          | -128        |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 7           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.002322222 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 0.0166      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.42e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0029     |
# |    value_loss           | 1.95e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.6         |
# |    ep_rew_mean          | -46          |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 8            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0027727406 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 0.048        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.09e+04     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00259     |
# |    value_loss           | 1.42e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29           |
# |    ep_rew_mean          | -11.9        |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 9            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0005463448 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 0.025        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07e+05     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 1.51e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28           |
# |    ep_rew_mean          | 71.8         |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 10           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0039337357 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 0.0176       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.76e+04     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 1.55e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.1        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 11          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.002128427 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.94       |
# |    explained_variance   | 0.0481      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.72e+04    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 1.77e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.5         |
# |    ep_rew_mean          | -236         |
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 12           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0030762395 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.94        |
# |    explained_variance   | 0.0439       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.93e+04     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 1.56e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.1         |
# |    ep_rew_mean          | -13.3        |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 13           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0006032884 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 0.0798       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.03e+04     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 1.36e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.3          |
# |    ep_rew_mean          | 0.5           |
# | time/                   |               |
# |    fps                  | 586           |
# |    iterations           | 14            |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00042062008 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.95         |
# |    explained_variance   | 0.0362        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.78e+04      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00115      |
# |    value_loss           | 1.76e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.7         |
# |    ep_rew_mean          | 116          |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 15           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0006361712 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 0.0738       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.94e+04     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 1.71e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 30.3          |
# |    ep_rew_mean          | 122           |
# | time/                   |               |
# |    fps                  | 584           |
# |    iterations           | 16            |
# |    time_elapsed         | 56            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00093384774 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.95         |
# |    explained_variance   | 0.0745        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.9e+04       |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.00183      |
# |    value_loss           | 1.67e+05      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.2        |
# |    ep_rew_mean          | -67.7       |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 17          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.000494172 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.95       |
# |    explained_variance   | 0.042       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.56e+04    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00118    |
# |    value_loss           | 1.6e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34           |
# |    ep_rew_mean          | -12.8        |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 18           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0007423337 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 0.0848       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.31e+04     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 1.49e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.9         |
# |    ep_rew_mean          | 60.8         |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 19           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0012849603 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.94        |
# |    explained_variance   | 0.0431       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.42e+04     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00185     |
# |    value_loss           | 1.44e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.2         |
# |    ep_rew_mean          | -76.1        |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 20           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0011412858 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.94        |
# |    explained_variance   | 0.122        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.08e+04     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00196     |
# |    value_loss           | 1.33e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.3         |
# |    ep_rew_mean          | -229         |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 21           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0011342482 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.93        |
# |    explained_variance   | 0.0799       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.56e+04     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 1.43e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.8         |
# |    ep_rew_mean          | -243         |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 22           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0010311882 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.93        |
# |    explained_variance   | 0.00539      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.44e+04     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 1.15e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.7         |
# |    ep_rew_mean          | -192         |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 23           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0012565571 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.92        |
# |    explained_variance   | 0.051        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.36e+04     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 1.5e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.1         |
# |    ep_rew_mean          | -144         |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 24           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0016519232 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.91        |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.5e+04      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 1.19e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.6         |
# |    ep_rew_mean          | 8.4          |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 25           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0010528716 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.9         |
# |    explained_variance   | 0.0397       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.17e+04     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 1.31e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.3         |
# |    ep_rew_mean          | -43.7        |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 26           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0026035453 |
# |    clip_fraction        | 0.00361      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.9         |
# |    explained_variance   | 0.0349       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.34e+04     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.004       |
# |    value_loss           | 1.62e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.2         |
# |    ep_rew_mean          | -45.1        |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 27           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0003458753 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.91        |
# |    explained_variance   | 0.0834       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.06e+04     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000856    |
# |    value_loss           | 1.12e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.2         |
# |    ep_rew_mean          | 28.6         |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 28           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0021390829 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.9         |
# |    explained_variance   | 0.115        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.23e+04     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 1.35e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.7         |
# |    ep_rew_mean          | -39.7        |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 29           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0005041578 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.88        |
# |    explained_variance   | 0.0928       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.15e+04     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000985    |
# |    value_loss           | 1.5e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.9         |
# |    ep_rew_mean          | -265         |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 30           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0010011506 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.87        |
# |    explained_variance   | 0.142        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.12e+04     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 1.29e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.5         |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 31           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0005449645 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.86        |
# |    explained_variance   | 0.00651      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.88e+04     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000879    |
# |    value_loss           | 1.25e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.1         |
# |    ep_rew_mean          | 13.5         |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 32           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0017600792 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.84        |
# |    explained_variance   | 0.0519       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.42e+04     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 1.61e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.7       |
# |    ep_rew_mean          | -6.4       |
# | time/                   |            |
# |    fps                  | 583        |
# |    iterations           | 33         |
# |    time_elapsed         | 115        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00231876 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.83      |
# |    explained_variance   | 0.049      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.12e+04   |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00187   |
# |    value_loss           | 1.56e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.7         |
# |    ep_rew_mean          | -55.2        |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 34           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0039861323 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.83        |
# |    explained_variance   | 0.215        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.5e+04      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 1.14e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35           |
# |    ep_rew_mean          | -26.8        |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 35           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0026387563 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.83        |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.46e+04     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00215     |
# |    value_loss           | 1.28e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.2         |
# |    ep_rew_mean          | -5.4         |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 36           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0010350422 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.8         |
# |    explained_variance   | 0.0535       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.54e+04     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 1.39e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.9         |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 37           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0007214945 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.44e+04     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 1.5e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.6         |
# |    ep_rew_mean          | -196         |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 38           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0022227624 |
# |    clip_fraction        | 0.00112      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0.12         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.81e+04     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 1.21e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.5        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 39          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.002265037 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.94e+04    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 1.32e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.1        |
# |    ep_rew_mean          | -175        |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 40          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.002085852 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.77       |
# |    explained_variance   | 0.0828      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.41e+04    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 1.44e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.2         |
# |    ep_rew_mean          | -147         |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 41           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0020225937 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.75        |
# |    explained_variance   | 0.199        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.52e+04     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 1.14e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.4         |
# |    ep_rew_mean          | 12.7         |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 42           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0037335097 |
# |    clip_fraction        | 0.00903      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.76        |
# |    explained_variance   | 0.152        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09e+05     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 1.55e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.5       |
# |    ep_rew_mean          | -62.4      |
# | time/                   |            |
# |    fps                  | 583        |
# |    iterations           | 43         |
# |    time_elapsed         | 150        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.00157457 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.77      |
# |    explained_variance   | 0.0944     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.59e+04   |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00125   |
# |    value_loss           | 1.52e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.4        |
# |    ep_rew_mean          | 3.7         |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 44          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.002395986 |
# |    clip_fraction        | 0.000146    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | 0.0316      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.06e+04    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.000869   |
# |    value_loss           | 1.57e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.2          |
# |    ep_rew_mean          | 14.8          |
# | time/                   |               |
# |    fps                  | 584           |
# |    iterations           | 45            |
# |    time_elapsed         | 157           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00045141863 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.72         |
# |    explained_variance   | 0.108         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8e+04         |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.00138      |
# |    value_loss           | 1.51e+05      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.9        |
# |    ep_rew_mean          | -64         |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 46          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.000814195 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.71       |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.38e+04    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00124    |
# |    value_loss           | 1.37e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.2        |
# |    ep_rew_mean          | -50.2       |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 47          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.002767323 |
# |    clip_fraction        | 0.000928    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.72       |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.18e+04    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00251    |
# |    value_loss           | 1.36e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.9         |
# |    ep_rew_mean          | 21.4         |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 48           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0005176078 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.73        |
# |    explained_variance   | 0.194        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.14e+04     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000885    |
# |    value_loss           | 1.33e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28           |
# |    ep_rew_mean          | -132         |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 49           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0007272978 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.72        |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.45e+04     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 1.36e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.2         |
# |    ep_rew_mean          | -62.7        |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 50           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0009385206 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.69        |
# |    explained_variance   | 0.156        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.68e+04     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 1.26e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29.4          |
# |    ep_rew_mean          | -48           |
# | time/                   |               |
# |    fps                  | 585           |
# |    iterations           | 51            |
# |    time_elapsed         | 178           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00059818476 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.69         |
# |    explained_variance   | 0.18          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.74e+04      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.00122      |
# |    value_loss           | 1.29e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.1         |
# |    ep_rew_mean          | -127         |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 52           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0045229583 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.7         |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.97e+04     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00305     |
# |    value_loss           | 1.3e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.6         |
# |    ep_rew_mean          | -168         |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 53           |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0011334313 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.71        |
# |    explained_variance   | 0.277        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.1e+04      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 1.21e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.9         |
# |    ep_rew_mean          | -177         |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 54           |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0010559838 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.72        |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.44e+04     |
# ...
# |    fps                  | 604          |
# |    iterations           | 569          |
# |    time_elapsed         | 1926         |
# |    total_timesteps      | 1165312      |
# | train/                  |              |
# |    approx_kl            | 0.0020116218 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.03e+03     |
# |    n_updates            | 5680         |
# |    policy_gradient_loss | -0.0036      |
# |    value_loss           | 9.2e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.38         |
# |    ep_rew_mean          | 1.01e+03     |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 570          |
# |    time_elapsed         | 1930         |
# |    total_timesteps      | 1167360      |
# | train/                  |              |
# |    approx_kl            | 0.0035221647 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3e+03        |
# |    n_updates            | 5690         |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 2.4e+04      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.98        |
# |    ep_rew_mean          | 954         |
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 571         |
# |    time_elapsed         | 1933        |
# |    total_timesteps      | 1169408     |
# | train/                  |             |
# |    approx_kl            | 0.002752662 |
# |    clip_fraction        | 0.0184      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.65e+03    |
# |    n_updates            | 5700        |
# |    policy_gradient_loss | -0.0035     |
# |    value_loss           | 1.03e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.85        |
# |    ep_rew_mean          | 1.08e+03    |
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 572         |
# |    time_elapsed         | 1936        |
# |    total_timesteps      | 1171456     |
# | train/                  |             |
# |    approx_kl            | 0.004126062 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 930         |
# |    n_updates            | 5710        |
# |    policy_gradient_loss | -0.00588    |
# |    value_loss           | 7.46e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.22         |
# |    ep_rew_mean          | 946          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 573          |
# |    time_elapsed         | 1940         |
# |    total_timesteps      | 1173504      |
# | train/                  |              |
# |    approx_kl            | 0.0070085186 |
# |    clip_fraction        | 0.072        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.74e+03     |
# |    n_updates            | 5720         |
# |    policy_gradient_loss | -0.00934     |
# |    value_loss           | 1.87e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.06         |
# |    ep_rew_mean          | 1.1e+03      |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 574          |
# |    time_elapsed         | 1943         |
# |    total_timesteps      | 1175552      |
# | train/                  |              |
# |    approx_kl            | 0.0024019643 |
# |    clip_fraction        | 0.00713      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.72         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.2e+03      |
# |    n_updates            | 5730         |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 2.37e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.88        |
# |    ep_rew_mean          | 922         |
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 575         |
# |    time_elapsed         | 1947        |
# |    total_timesteps      | 1177600     |
# | train/                  |             |
# |    approx_kl            | 0.002403583 |
# |    clip_fraction        | 0.00742     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.19e+03    |
# |    n_updates            | 5740        |
# |    policy_gradient_loss | -0.00318    |
# |    value_loss           | 7.63e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.58         |
# |    ep_rew_mean          | 900          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 576          |
# |    time_elapsed         | 1951         |
# |    total_timesteps      | 1179648      |
# | train/                  |              |
# |    approx_kl            | 0.0052633174 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.848        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.93e+03     |
# |    n_updates            | 5750         |
# |    policy_gradient_loss | -0.0044      |
# |    value_loss           | 1.5e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.4          |
# |    ep_rew_mean          | 965          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 577          |
# |    time_elapsed         | 1954         |
# |    total_timesteps      | 1181696      |
# | train/                  |              |
# |    approx_kl            | 0.0013437029 |
# |    clip_fraction        | 0.00288      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35e+03     |
# |    n_updates            | 5760         |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 8.56e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.89         |
# |    ep_rew_mean          | 1.04e+03     |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 578          |
# |    time_elapsed         | 1958         |
# |    total_timesteps      | 1183744      |
# | train/                  |              |
# |    approx_kl            | 0.0020414004 |
# |    clip_fraction        | 0.0062       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.917        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+03     |
# |    n_updates            | 5770         |
# |    policy_gradient_loss | -0.00377     |
# |    value_loss           | 6.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.9          |
# |    ep_rew_mean          | 1.03e+03     |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 579          |
# |    time_elapsed         | 1961         |
# |    total_timesteps      | 1185792      |
# | train/                  |              |
# |    approx_kl            | 0.0031533693 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.14e+03     |
# |    n_updates            | 5780         |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 7.79e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.34         |
# |    ep_rew_mean          | 969          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 580          |
# |    time_elapsed         | 1965         |
# |    total_timesteps      | 1187840      |
# | train/                  |              |
# |    approx_kl            | 0.0014295753 |
# |    clip_fraction        | 0.00327      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.92e+03     |
# |    n_updates            | 5790         |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 2.06e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.73         |
# |    ep_rew_mean          | 1.11e+03     |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 581          |
# |    time_elapsed         | 1968         |
# |    total_timesteps      | 1189888      |
# | train/                  |              |
# |    approx_kl            | 0.0028738868 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.88e+03     |
# |    n_updates            | 5800         |
# |    policy_gradient_loss | -0.00392     |
# |    value_loss           | 1.47e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.43         |
# |    ep_rew_mean          | 1.06e+03     |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 582          |
# |    time_elapsed         | 1972         |
# |    total_timesteps      | 1191936      |
# | train/                  |              |
# |    approx_kl            | 0.0033740068 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.31e+03     |
# |    n_updates            | 5810         |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 8.44e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.71         |
# |    ep_rew_mean          | 1.01e+03     |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 583          |
# |    time_elapsed         | 1975         |
# |    total_timesteps      | 1193984      |
# | train/                  |              |
# |    approx_kl            | 0.0011527379 |
# |    clip_fraction        | 0.00479      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.868        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.02e+03     |
# |    n_updates            | 5820         |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 1.14e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14         |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 584          |
# |    time_elapsed         | 1979         |
# |    total_timesteps      | 1196032      |
# | train/                  |              |
# |    approx_kl            | 0.0021117982 |
# |    clip_fraction        | 0.00498      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.876        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.65e+03     |
# |    n_updates            | 5830         |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 1.27e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.63         |
# |    ep_rew_mean          | 989          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 585          |
# |    time_elapsed         | 1982         |
# |    total_timesteps      | 1198080      |
# | train/                  |              |
# |    approx_kl            | 0.0015565138 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.32e+03     |
# |    n_updates            | 5840         |
# |    policy_gradient_loss | -0.00449     |
# |    value_loss           | 8.59e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.77         |
# |    ep_rew_mean          | 1.02e+03     |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 586          |
# |    time_elapsed         | 1986         |
# |    total_timesteps      | 1200128      |
# | train/                  |              |
# |    approx_kl            | 0.0019154897 |
# |    clip_fraction        | 0.00596      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.898        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.55e+03     |
# |    n_updates            | 5850         |
# |    policy_gradient_loss | -0.00373     |
# |    value_loss           | 1.07e+04     |
# ------------------------------------------

# %% [markdown]
# # Save Model

# %%
model.save('DeterministicTraining2')

# %% [markdown]
# # Evaluate Model

# %%
scenarioEnv = DeterministicScenarioEnvironment(13, 19, 21, 4, 2, 2, 2, 0, 0)
sampleEnvObs = scenarioEnv.reset()
done = False
score = 0 

while not done:
    action, _ = model.predict(sampleEnvObs)
    sampleEnvObs, reward, done, info = scenarioEnv.step(action)
    score+=reward
    print('Score:{} Action:{} State:{}'.format(score, action, [sampleEnvObs["missiles"],sampleEnvObs["expectedShipDamage"], sampleEnvObs["currentShipDamage"], sampleEnvObs["assets"]]))
scenarioEnv.close()
# Out:
# Score:160 Action:[1 3 1 1] State:[9, array([4, 2, 2, 2, 0, 0]), array([0, 2, 0, 2, 0, 0]), array([19, 21])]
# Score:140 Action:[4 3 1 1] State:[9, array([4, 2, 2, 2, 0, 0]), array([0, 2, 0, 2, 0, 0]), array([19, 21])]
# Score:60 Action:[4 5 1 1] State:[5, array([4, 2, 2, 2, 0, 0]), array([0, 2, 0, 2, 2, 2]), array([19, 21])]
# Score:220 Action:[2 0 1 1] State:[1, array([4, 2, 2, 2, 0, 0]), array([2, 2, 2, 2, 2, 2]), array([19, 21])]
# Score:20 Action:[2 0 1 1] State:[-3, array([4, 2, 2, 2, 0, 0]), array([4, 2, 4, 2, 2, 2]), array([19, 21])]
