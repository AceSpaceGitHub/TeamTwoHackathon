# %% [markdown]
# 1. Import Dependencies

# %%
# !pip install gym
# !pip install stable_baselines3
# Out:
# Requirement already satisfied: gym in c:\python38\lib\site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\python38\lib\site-packages (from gym) (1.19.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\python38\lib\site-packages (from gym) (2.0.0)
# WARNING: Ignoring invalid distribution -umpy (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python38\lib\site-packages)
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: stable_baselines3 in c:\python38\lib\site-packages (1.2.0)
# Requirement already satisfied: numpy in c:\python38\lib\site-packages (from stable_baselines3) (1.19.5)
# Requirement already satisfied: cloudpickle in c:\python38\lib\site-packages (from stable_baselines3) (2.0.0)
# Requirement already satisfied: gym>=0.17 in c:\python38\lib\site-packages (from stable_baselines3) (0.21.0)
# Requirement already satisfied: pandas in c:\python38\lib\site-packages (from stable_baselines3) (1.3.3)
# Requirement already satisfied: torch>=1.8.1 in c:\python38\lib\site-packages (from stable_baselines3) (1.9.1)
# Requirement already satisfied: matplotlib in c:\python38\lib\site-packages (from stable_baselines3) (3.4.3)
# Requirement already satisfied: typing-extensions in c:\python38\lib\site-packages (from torch>=1.8.1->stable_baselines3) (3.7.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python38\lib\site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python38\lib\site-packages (from matplotlib->stable_baselines3) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\python38\lib\site-packages (from matplotlib->stable_baselines3) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\python38\lib\site-packages (from matplotlib->stable_baselines3) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python38\lib\site-packages (from matplotlib->stable_baselines3) (1.3.2)
# Requirement already satisfied: pytz>=2017.3 in c:\python38\lib\site-packages (from pandas->stable_baselines3) (2021.3)
# Requirement already satisfied: six in c:\python38\lib\site-packages (from cycler>=0.10->matplotlib->stable_baselines3) (1.15.0)
# WARNING: Ignoring invalid distribution -umpy (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python38\lib\site-packages)
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\python38\python.exe -m pip install --upgrade pip' command.

# %%
import gym
from gym import Env
from gym.spaces import Discrete, Dict, MultiBinary, MultiDiscrete, Box
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env

# %% [markdown]
# # Building an Environment

# %%
class ScenarioManager:
    def getActionSpace(self):
        return MultiDiscrete([6, 6, 2, 2])
    def getObservationSpace(self):
        return Dict({"missiles": Discrete(100), 
        "expectedShipDamage": MultiDiscrete([3,3,3,3,3,3]), 
        "currentShipDamage": MultiDiscrete([3,3,3,3,3,3]), 
        "target1Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target2Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target3Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target4Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target5Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target6Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target1Targets": MultiBinary(6),
        "target2Targets": MultiBinary(6),
        "target3Targets": MultiBinary(6),
        "target4Targets": MultiBinary(6),
        "target5Targets": MultiBinary(6),
        "target6Targets": MultiBinary(6),
        "assets": MultiDiscrete([100,100])})
    def getRandomizedState(self):
        return {"missiles": random.randint(1, 99),
         "expectedShipDamage": 
         np.array([random.randint(0, 2), 
         random.randint(0, 2), 
         random.randint(0, 2), 
         random.randint(0, 2), 
         random.randint(0, 2), 
         random.randint(0, 2)]), 
         "currentShipDamage": np.array([0,0,0,0,0,0]),
         "target1Defense": np.array([random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75)]),
         "target2Defense": np.array([random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75)]),
         "target3Defense": np.array([random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75)]),
         "target4Defense": np.array([random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75)]),
         "target5Defense": np.array([random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75)]),
         "target6Defense": np.array([random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75),random.randint(0,75)]),
        #  "target1Targets": np.array([1, 0, 1, 0 , 0, 0]),
        #  "target2Targets": np.array([0, 1, 0, 1 , 0, 0]),
        #  "target3Targets": np.array([1, 0, 1, 0 , 0, 0]),
        #  "target4Targets": np.array([0, 1, 0, 1 , 0, 0]),
        #  "target5Targets": np.array([0, 0, 0, 0 , 1, 1]),
        #  "target6Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "target1Targets": np.array([1, random.randint(0,1), random.randint(0,1), random.randint(0,1), random.randint(0,1), random.randint(0,1)]),
         "target2Targets": np.array([random.randint(0,1), 1, random.randint(0,1), random.randint(0,1), random.randint(0,1), random.randint(0,1)]),
         "target3Targets": np.array([random.randint(0,1), random.randint(0,1), 1, random.randint(0,1), random.randint(0,1), random.randint(0,1)]),
         "target4Targets": np.array([random.randint(0,1), random.randint(0,1), random.randint(0,1), 1, random.randint(0,1), random.randint(0,1)]),
         "target5Targets": np.array([random.randint(0,1), random.randint(0,1), random.randint(0,1), random.randint(0,1) , 1, random.randint(0,1)]),
         "target6Targets": np.array([random.randint(0,1), random.randint(0,1), random.randint(0,1), random.randint(0,1) , random.randint(0,1), 1]),
         "assets": np.array([random.randint(1, 99), random.randint(1, 99)])}
    def getState(self, numberOfmissiles, numberOfJets, numberOfPilots, tD1, tD2, tD3, tD4, tD5, tD6):
        return {"missiles": numberOfmissiles,
         "expectedShipDamage": np.array([tD1, tD2, tD3, tD4, tD5, tD6]), 
         "currentShipDamage": np.array([0,0,0,0,0,0]),
         "target1Defense": np.array([0,0,25,0,15,0]),
         "target2Defense": np.array([0,0,0,25,0,15]),
         "target3Defense": np.array([0,0,30,0,0,0]),
         "target4Defense": np.array([0,0,0,30,0,0]),
         "target5Defense": np.array([0,0,0,0,40,0]),
         "target6Defense": np.array([0,0,0,0,0,40]),
         "target1Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target2Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target3Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target4Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target5Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "target6Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "assets": np.array([numberOfJets ,numberOfPilots])}
    def canAttack(self, state, sortiArray, ship1, ship2):
        canAttack = False
        reward = -100
        # Check if can attack
        for sorti in sortiArray:
            if state[sorti][ship1] and state[sorti][ship2]:
                canAttack = True
                reward = 2
                break
        return canAttack, reward
    def shouldAttack(self, state, defenseArray, ship):
        reward = 0
        shouldAttack = True
        # Check if ship is already more damaged than expected
        if state["currentShipDamage"][ship] >= state["expectedShipDamage"][ship]:
            # Check to see if target posses a threat
            if(state["currentShipDamage"][ship] == 0 and state[defenseArray[ship]][ship] > 0):
                # Reward for damaging a ship that is a threat?
                reward = 0
            else:
                # no threat and already at expected damage
                reward = -200
                shouldAttack = False
        else:
            # targetted a ship worth targetting
            reward = 50
        return shouldAttack, reward
    def defendShip(self, state, defenseArray, ship):
        shotDown = False
        length = len(state[defenseArray[ship]])
        for index in range(0, length):
            if(state[defenseArray[ship]][index] > 0):
                roll = random.randint(0,100)
                if(roll <= state[defenseArray[ship]][index]):
                    shotDown = True
        return shotDown
    def shootShip(self, state, ship, defenseArray):
        reward = 0
        roll = random.randint(0, 100)
        if roll <= 60:
            # Should we reward more here?
            state["currentShipDamage"][ship] = max(1, state["currentShipDamage"][ship])
            for index in defenseArray:
                state[index][ship] = 0
        
            roll = random.randint(0, 100)
            if roll <= 50:
                # Should we reward more here?
                state["currentShipDamage"][ship] = max(2, state["currentShipDamage"][ship])
        
        return reward
    def step(self, state, action):
        # Set placeholder for info
        info = {}
        reward = 0
        done = False
        numberOfTargets = 6
        defenseArray = ["target1Defense", "target2Defense", "target3Defense", "target4Defense", "target5Defense", "target6Defense"]
        sortieArray = ["target1Targets", "target2Targets", "target3Targets", "target4Targets", "target5Targets", "target6Targets"]

        # Should we reward here or after hit or even after checking against expected damage?
        ship1Index = action[0]
        ship2Index = action[1]

        canAttack , canAttackReward = self.canAttack(state, sortieArray, ship1Index, ship2Index)

        if canAttack:
            shouldAttack, shouldAttackReward1 = self.shouldAttack(state, sortieArray, ship1Index)
            shouldAttack2, shouldAttackReward2 = self.shouldAttack(state, sortieArray, ship2Index)

            shotDown1 = self.defendShip(state, defenseArray, ship1Index)
            shotDown2 = self.defendShip(state, defenseArray, ship2Index)

            if ship1Index == ship2Index:
                if shotDown1:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1
            else:
                if shotDown1:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1
                if shotDown2:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1

            self.shootShip(state, ship1Index, defenseArray)
            state["missiles"] -= 1
            if action[2] == 1:
                self.shootShip(state, ship1Index, defenseArray)
                state["missiles"] -= 1
            self.shootShip(state, ship2Index, defenseArray)
            state["missiles"] -= 1
            if action[3] == 1:
                self.shootShip(state, ship2Index, defenseArray)
                state["missiles"] -= 1

            reward = canAttackReward + shouldAttackReward1 + shouldAttackReward2
        else:
            # Can't attack we are done
            return state, canAttackReward, False, info
        
        # ############# Ideas #################
        # Add bonus for end state for each asset, maybe more for pilots and jets
        # Add offset rewards for pilots and jets
        # Add a calculated ratio reward for threats in the defending arrays

        # Add penatly for going over on assets
        if state["missiles"] < 0:
            reward -= 200

        if state ["assets"][0] < 0:
            reward -= 200

        if state ["assets"][1] < 0:
            reward -= 200

        isExpectedDamageMet = True
        for shipIndex in range(0, numberOfTargets):
            if state["currentShipDamage"][shipIndex] < state["expectedShipDamage"][shipIndex]:
                isExpectedDamageMet = False
                break

        if isExpectedDamageMet:
            reward += 300
            done = True

        if state["missiles"] <= 0:
            done = True

        if state["assets"][0] <= 0 or state["assets"][1] <= 0:
            done = True
        
        # Return step information
        return state, reward, done, info

class ScenarioEnv(Env):
    def __init__(self, numberOfmissiles, numberOfJets, numberOfPilots, tD1, tD2, tD3, tD4, tD5, tD6):
        manager = ScenarioManager()
        self.manager = manager
        # Actions we can take: 0 - Do Nothing, 1 - Launch
        self.action_space = manager.getActionSpace()
        # Target Damage state array: 0 - Untouched, 1 - Disabled, 2 - Destroyed
        self.observation_space = manager.getObservationSpace()
        # store initial state
        self.numberOfmissiles = numberOfmissiles
        self.numberOfJets = numberOfJets
        self.numberOfPilots = numberOfPilots
        self.tD1 = tD1
        self.tD2 = tD2
        self.tD3 = tD3
        self.tD4 = tD4
        self.tD5 = tD5
        self.tD6 = tD6
        # Set start state
        self.state = self.manager.getState(self.numberOfmissiles, self.numberOfJets, self.numberOfPilots, self.tD1, self.tD2, self.tD3, self.tD4, self.tD5, self.tD6)

    def step(self, action):
        # Return step information
        return self.manager.step(self.state, action)

    def render(self):
        # Implement viz
        pass

    def reset(self):
        # Reset shower temperature
        self.state = self.manager.getState(self.numberOfmissiles, self.numberOfJets, self.numberOfPilots, self.tD1, self.tD2, self.tD3, self.tD4, self.tD5, self.tD6)
        return self.state

class TrainingScenarioEnv(Env):
    def __init__(self):
        manager = ScenarioManager()
        self.manager = manager
        # Actions we can take: 0 - Do Nothing, 1 - Launch
        self.action_space = manager.getActionSpace()
        # Target Damage state array: 0 - Untouched, 1 - Disabled, 2 - Destroyed
        self.observation_space = manager.getObservationSpace()
        # Set start state
        self.state = manager.getRandomizedState()

    def step(self, action):
        # Return step information
        return self.manager.step(self.state, action)

    def render(self):
        # Implement viz
        pass

    def reset(self):
        # Reset shower temperature
        self.state = self.manager.getRandomizedState()
        return self.state

# %% [markdown]
# Check Training Environment

# %%
trainingEnv=TrainingScenarioEnv()
check_env(trainingEnv, warn=True)

# %% [markdown]
# Check Scenario Environment

# %% [markdown]
# # Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
trainingEnv.reset()
model = PPO("MultiInputPolicy", trainingEnv, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# 30ish minute training
#model.learn(total_timesteps=400000)

model.learn(total_timesteps=5000000)
# Out:
# Logging to Training\Logs\PPO_54
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 8.48      |
# |    ep_rew_mean     | -1.12e+03 |
# | time/              |           |
# |    fps             | 527       |
# |    iterations      | 1         |
# |    time_elapsed    | 3         |
# |    total_timesteps | 2048      |
# ----------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.5           |
# |    ep_rew_mean          | -1.51e+03     |
# | time/                   |               |
# |    fps                  | 475           |
# |    iterations           | 2             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00020652334 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | -2.5e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.51e+05      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00141      |
# |    value_loss           | 1.68e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.83          |
# |    ep_rew_mean          | -1.43e+03     |
# | time/                   |               |
# |    fps                  | 460           |
# |    iterations           | 3             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00044630223 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 5.36e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.2e+06       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00203      |
# |    value_loss           | 2.2e+06       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.97          |
# |    ep_rew_mean          | -1.39e+03     |
# | time/                   |               |
# |    fps                  | 457           |
# |    iterations           | 4             |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00083118974 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 1.43e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.01e+06      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00243      |
# |    value_loss           | 2.08e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.97         |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 454          |
# |    iterations           | 5            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0003908615 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 9.54e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.3e+05      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 2.36e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.56         |
# |    ep_rew_mean          | -1e+03       |
# | time/                   |              |
# |    fps                  | 451          |
# |    iterations           | 6            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0006509315 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 4.77e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.46e+05     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00216     |
# |    value_loss           | 1.8e+06      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.44          |
# |    ep_rew_mean          | -1.2e+03      |
# | time/                   |               |
# |    fps                  | 450           |
# |    iterations           | 7             |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00025066908 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 3.58e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.62e+05      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00155      |
# |    value_loss           | 2.06e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.89          |
# |    ep_rew_mean          | -1.29e+03     |
# | time/                   |               |
# |    fps                  | 448           |
# |    iterations           | 8             |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00066809193 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.02e+06      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.00177      |
# |    value_loss           | 1.76e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.45         |
# |    ep_rew_mean          | -1.39e+03    |
# | time/                   |              |
# |    fps                  | 441          |
# |    iterations           | 9            |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0002332397 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06e+06     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 1.93e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.09         |
# |    ep_rew_mean          | -1.36e+03    |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 10           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0005281002 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.1e+05      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 2.03e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10.1          |
# |    ep_rew_mean          | -1.6e+03      |
# | time/                   |               |
# |    fps                  | 433           |
# |    iterations           | 11            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00030533547 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.96         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.26e+06      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00154      |
# |    value_loss           | 2.26e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.63          |
# |    ep_rew_mean          | -1.25e+03     |
# | time/                   |               |
# |    fps                  | 430           |
# |    iterations           | 12            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00024650808 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.96         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.41e+06      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00153      |
# |    value_loss           | 2.01e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.3          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 427          |
# |    iterations           | 13           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0006796074 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.1e+06      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 2.06e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.45          |
# |    ep_rew_mean          | -1.24e+03     |
# | time/                   |               |
# |    fps                  | 425           |
# |    iterations           | 14            |
# |    time_elapsed         | 67            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00015901698 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.96         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.14e+06      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00112      |
# |    value_loss           | 2.31e+06      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.89       |
# |    ep_rew_mean          | -1.52e+03  |
# | time/                   |            |
# |    fps                  | 423        |
# |    iterations           | 15         |
# |    time_elapsed         | 72         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00076172 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.96      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.08e+06   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0021    |
# |    value_loss           | 1.98e+06   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.04          |
# |    ep_rew_mean          | -1.32e+03     |
# | time/                   |               |
# |    fps                  | 422           |
# |    iterations           | 16            |
# |    time_elapsed         | 77            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00034214652 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.96         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.24e+05      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.00155      |
# |    value_loss           | 2.24e+06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.77        |
# |    ep_rew_mean          | -1e+03      |
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 17          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.000904065 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.95       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19e+06    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0021     |
# |    value_loss           | 2.16e+06    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.2           |
# |    ep_rew_mean          | -1.37e+03     |
# | time/                   |               |
# |    fps                  | 420           |
# |    iterations           | 18            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00042091843 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.95         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.88e+05      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.0015       |
# |    value_loss           | 1.67e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.32         |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 19           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0008898057 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+06     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00264     |
# |    value_loss           | 2.03e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.74          |
# |    ep_rew_mean          | -1.27e+03     |
# | time/                   |               |
# |    fps                  | 419           |
# |    iterations           | 20            |
# |    time_elapsed         | 97            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00048881664 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.95         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.77e+05      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00213      |
# |    value_loss           | 1.46e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.44         |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 21           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0013468727 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18e+06     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 1.98e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.15         |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 417          |
# |    iterations           | 22           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0002546599 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.85e+05     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 1.91e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.3          |
# |    ep_rew_mean          | -1.47e+03    |
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 23           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0010613531 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.94        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.41e+05     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 1.87e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.82         |
# |    ep_rew_mean          | -1.28e+03    |
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 24           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0023357165 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.93        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.11e+06     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 1.99e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7.6           |
# |    ep_rew_mean          | -952          |
# | time/                   |               |
# |    fps                  | 415           |
# |    iterations           | 25            |
# |    time_elapsed         | 123           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00090538367 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.92         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.06e+05      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.00278      |
# |    value_loss           | 1.88e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.62         |
# |    ep_rew_mean          | -932         |
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 26           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0020028085 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.92        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+06     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00392     |
# |    value_loss           | 1.83e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.68         |
# |    ep_rew_mean          | -1.5e+03     |
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 27           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0010217377 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.91        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.79e+05     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00299     |
# |    value_loss           | 1.54e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.19         |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 28           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0013559398 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.9         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35e+06     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 2.21e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.1         |
# |    ep_rew_mean          | -1.08e+03   |
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 29          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004924398 |
# |    clip_fraction        | 0.00396     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.88       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.18e+05    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00472    |
# |    value_loss           | 1.77e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.11         |
# |    ep_rew_mean          | -1.34e+03    |
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 30           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0018895408 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.85e+05     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00346     |
# |    value_loss           | 1.52e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.5         |
# |    ep_rew_mean          | -1.26e+03   |
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 31          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.004603524 |
# |    clip_fraction        | 0.00493     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.82       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.1e+05     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00418    |
# |    value_loss           | 1.63e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.07         |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 32           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0017049017 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.82        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.04e+05     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 1.57e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.99        |
# |    ep_rew_mean          | -1.34e+03   |
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 33          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.003943136 |
# |    clip_fraction        | 0.00342     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.81       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+06    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 1.57e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.63         |
# |    ep_rew_mean          | -1.04e+03    |
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 34           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0010877287 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.19e+05     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00264     |
# |    value_loss           | 2e+06        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.26        |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 35          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004417829 |
# |    clip_fraction        | 0.0061      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.77       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.66e+05    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00462    |
# |    value_loss           | 1.82e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.96        |
# |    ep_rew_mean          | -1.12e+03   |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 36          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005578365 |
# |    clip_fraction        | 0.0213      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.7        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.34e+05    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00716    |
# |    value_loss           | 1.6e+06     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.1          |
# |    ep_rew_mean          | -892         |
# | time/                   |              |
# |    fps                  | 407          |
# |    iterations           | 37           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0038490808 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.68        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.43e+05     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00632     |
# |    value_loss           | 1.52e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.1          |
# |    ep_rew_mean          | -1.01e+03    |
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 38           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0039692298 |
# |    clip_fraction        | 0.00796      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.69        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.72e+05     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00717     |
# |    value_loss           | 1.1e+06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.51         |
# |    ep_rew_mean          | -1.2e+03     |
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 39           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0049147177 |
# |    clip_fraction        | 0.00806      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.69        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.84e+05     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00722     |
# |    value_loss           | 1.3e+06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.87         |
# |    ep_rew_mean          | -991         |
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 40           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0019861315 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.7         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.8e+05      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 1.43e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.09        |
# |    ep_rew_mean          | -981        |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 41          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.005444224 |
# |    clip_fraction        | 0.0121      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.67       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.48e+05    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00772    |
# |    value_loss           | 1.34e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.06         |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 404          |
# |    iterations           | 42           |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0024766298 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.64        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.19e+05     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00481     |
# |    value_loss           | 1.19e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.29        |
# |    ep_rew_mean          | -1.12e+03   |
# | time/                   |             |
# |    fps                  | 403         |
# |    iterations           | 43          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.003747703 |
# |    clip_fraction        | 0.00479     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.84e+05    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00584    |
# |    value_loss           | 1.21e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.92         |
# |    ep_rew_mean          | -958         |
# | time/                   |              |
# |    fps                  | 403          |
# |    iterations           | 44           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0048392992 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.04e+05     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00809     |
# |    value_loss           | 1.35e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.48         |
# |    ep_rew_mean          | -893         |
# | time/                   |              |
# |    fps                  | 402          |
# |    iterations           | 45           |
# |    time_elapsed         | 228          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0045642033 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.56        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.79e+05     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00727     |
# |    value_loss           | 1.2e+06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.89         |
# |    ep_rew_mean          | -636         |
# | time/                   |              |
# |    fps                  | 402          |
# |    iterations           | 46           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0047992417 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.51        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.56e+05     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00646     |
# |    value_loss           | 1.29e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.47         |
# |    ep_rew_mean          | -903         |
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 47           |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0050223907 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.49        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.51e+05     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00871     |
# |    value_loss           | 1.09e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.87         |
# |    ep_rew_mean          | -918         |
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 48           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0046226387 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.52        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.45e+05     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 1.07e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.25        |
# |    ep_rew_mean          | -545        |
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 49          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.005143019 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.81e+05    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 1.37e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.67        |
# |    ep_rew_mean          | -932        |
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 50          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.004587747 |
# |    clip_fraction        | 0.0134      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.3e+05     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00979    |
# |    value_loss           | 9.31e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.38        |
# |    ep_rew_mean          | -858        |
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 51          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.004809699 |
# |    clip_fraction        | 0.0136      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.44       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.57e+05    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 9.7e+05     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.6       |
# |    ep_rew_mean          | -647      |
# | time/                   |           |
# |    fps                  | 399       |
# |    iterations           | 52        |
# |    time_elapsed         | 266       |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 0.0053902 |
# |    clip_fraction        | 0.0209    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.43     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.33e+05  |
# |    n_updates            | 510       |
# |    policy_gradient_loss | -0.0111   |
# |    value_loss           | 1.07e+06  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.88         |
# |    ep_rew_mean          | -839         |
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 53           |
# |    time_elapsed         | 271          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0062313667 |
# |    clip_fraction        | 0.0455       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.45        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.97e+05     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0177      |
# |    value_loss           | 8.31e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.21        |
# |    ep_rew_mean          | -503        |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 54          |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.006988779 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.7e+05     |
# ...
# |    ep_len_mean          | 4.93         |
# |    ep_rew_mean          | 703          |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 2425         |
# |    time_elapsed         | 12498        |
# |    total_timesteps      | 4966400      |
# | train/                  |              |
# |    approx_kl            | 0.0056657502 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.343       |
# |    explained_variance   | 0.664        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.6e+03      |
# |    n_updates            | 24240        |
# |    policy_gradient_loss | -0.0146      |
# |    value_loss           | 9.6e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.76        |
# |    ep_rew_mean          | 803         |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 2426        |
# |    time_elapsed         | 12503       |
# |    total_timesteps      | 4968448     |
# | train/                  |             |
# |    approx_kl            | 0.005379383 |
# |    clip_fraction        | 0.0399      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.327      |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48e+03    |
# |    n_updates            | 24250       |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 9.18e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.63         |
# |    ep_rew_mean          | 783          |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 2427         |
# |    time_elapsed         | 12508        |
# |    total_timesteps      | 4970496      |
# | train/                  |              |
# |    approx_kl            | 0.0053506284 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.341       |
# |    explained_variance   | 0.63         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.86e+03     |
# |    n_updates            | 24260        |
# |    policy_gradient_loss | -0.0127      |
# |    value_loss           | 1.02e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.49        |
# |    ep_rew_mean          | 747         |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 2428        |
# |    time_elapsed         | 12513       |
# |    total_timesteps      | 4972544     |
# | train/                  |             |
# |    approx_kl            | 0.006703387 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.36       |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 983         |
# |    n_updates            | 24270       |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 8.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.86        |
# |    ep_rew_mean          | 761         |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 2429        |
# |    time_elapsed         | 12518       |
# |    total_timesteps      | 4974592     |
# | train/                  |             |
# |    approx_kl            | 0.005578291 |
# |    clip_fraction        | 0.0384      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.342      |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.93e+03    |
# |    n_updates            | 24280       |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 8.58e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.1          |
# |    ep_rew_mean          | 769          |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 2430         |
# |    time_elapsed         | 12523        |
# |    total_timesteps      | 4976640      |
# | train/                  |              |
# |    approx_kl            | 0.0050391713 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.365       |
# |    explained_variance   | 0.614        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.82e+03     |
# |    n_updates            | 24290        |
# |    policy_gradient_loss | -0.014       |
# |    value_loss           | 1.18e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.14         |
# |    ep_rew_mean          | 801          |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 2431         |
# |    time_elapsed         | 12529        |
# |    total_timesteps      | 4978688      |
# | train/                  |              |
# |    approx_kl            | 0.0042246217 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.314       |
# |    explained_variance   | 0.661        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.15e+03     |
# |    n_updates            | 24300        |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 1.08e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.05        |
# |    ep_rew_mean          | 816         |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 2432        |
# |    time_elapsed         | 12534       |
# |    total_timesteps      | 4980736     |
# | train/                  |             |
# |    approx_kl            | 0.004622898 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.34       |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.53e+03    |
# |    n_updates            | 24310       |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 9.51e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.7         |
# |    ep_rew_mean          | 797         |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 2433        |
# |    time_elapsed         | 12539       |
# |    total_timesteps      | 4982784     |
# | train/                  |             |
# |    approx_kl            | 0.004672571 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.326      |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57e+03    |
# |    n_updates            | 24320       |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 9.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.45        |
# |    ep_rew_mean          | 785         |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 2434        |
# |    time_elapsed         | 12544       |
# |    total_timesteps      | 4984832     |
# | train/                  |             |
# |    approx_kl            | 0.007903647 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.319      |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12e+03    |
# |    n_updates            | 24330       |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 9.1e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 825          |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 2435         |
# |    time_elapsed         | 12549        |
# |    total_timesteps      | 4986880      |
# | train/                  |              |
# |    approx_kl            | 0.0049981046 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | 0.637        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.42e+03     |
# |    n_updates            | 24340        |
# |    policy_gradient_loss | -0.0141      |
# |    value_loss           | 9.11e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.41        |
# |    ep_rew_mean          | 752         |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 2436        |
# |    time_elapsed         | 12554       |
# |    total_timesteps      | 4988928     |
# | train/                  |             |
# |    approx_kl            | 0.004643674 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.302      |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35e+03    |
# |    n_updates            | 24350       |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 9.15e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.33         |
# |    ep_rew_mean          | 738          |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 2437         |
# |    time_elapsed         | 12559        |
# |    total_timesteps      | 4990976      |
# | train/                  |              |
# |    approx_kl            | 0.0058579245 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71e+03     |
# |    n_updates            | 24360        |
# |    policy_gradient_loss | -0.0146      |
# |    value_loss           | 9.69e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.8          |
# |    ep_rew_mean          | 759          |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 2438         |
# |    time_elapsed         | 12564        |
# |    total_timesteps      | 4993024      |
# | train/                  |              |
# |    approx_kl            | 0.0057463325 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.339       |
# |    explained_variance   | 0.551        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.54e+03     |
# |    n_updates            | 24370        |
# |    policy_gradient_loss | -0.0138      |
# |    value_loss           | 1.62e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.59        |
# |    ep_rew_mean          | 768         |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 2439        |
# |    time_elapsed         | 12569       |
# |    total_timesteps      | 4995072     |
# | train/                  |             |
# |    approx_kl            | 0.003944086 |
# |    clip_fraction        | 0.0393      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.307      |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.97e+03    |
# |    n_updates            | 24380       |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 1.11e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.76        |
# |    ep_rew_mean          | 792         |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 2440        |
# |    time_elapsed         | 12574       |
# |    total_timesteps      | 4997120     |
# | train/                  |             |
# |    approx_kl            | 0.005444226 |
# |    clip_fraction        | 0.0408      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.33       |
# |    explained_variance   | 0.606       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.68e+03    |
# |    n_updates            | 24390       |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 1.11e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.88         |
# |    ep_rew_mean          | 693          |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 2441         |
# |    time_elapsed         | 12579        |
# |    total_timesteps      | 4999168      |
# | train/                  |              |
# |    approx_kl            | 0.0054991026 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | 0.679        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07e+03     |
# |    n_updates            | 24400        |
# |    policy_gradient_loss | -0.0144      |
# |    value_loss           | 8.13e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.26         |
# |    ep_rew_mean          | 739          |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 2442         |
# |    time_elapsed         | 12584        |
# |    total_timesteps      | 5001216      |
# | train/                  |              |
# |    approx_kl            | 0.0054974714 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.317       |
# |    explained_variance   | 0.634        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37e+03     |
# |    n_updates            | 24410        |
# |    policy_gradient_loss | -0.0152      |
# |    value_loss           | 9.4e+03      |
# ------------------------------------------

# %% [markdown]
# # Save Model

# %%
model.save('StretchTraining')

# %% [markdown]
# # Evaluate Model

# %%
scenarioEnv = ScenarioEnv(13, 19, 21, 2, 1, 1, 1, 0, 0)
sampleEnvObs = scenarioEnv.reset()
done = False
score = 0 

while not done:
    action, _ = model.predict(sampleEnvObs)
    sampleEnvObs, reward, done, info = scenarioEnv.step(action)
    score+=reward
    print('Score:{} Action:{} State:{}'.format(score, action, [sampleEnvObs["missiles"],sampleEnvObs["expectedShipDamage"], sampleEnvObs["currentShipDamage"], sampleEnvObs["assets"]]))
scenarioEnv.close()
# Out:
# Score:102 Action:[1 3 0 0] State:[11, array([2, 1, 1, 1, 0, 0]), array([0, 1, 0, 1, 0, 0]), array([18, 20])]
# Score:-296 Action:[3 1 0 0] State:[9, array([2, 1, 1, 1, 0, 0]), array([0, 2, 0, 1, 0, 0]), array([18, 20])]
# Score:-194 Action:[0 0 0 0] State:[7, array([2, 1, 1, 1, 0, 0]), array([2, 2, 0, 1, 0, 0]), array([18, 20])]
# Score:-294 Action:[2 3 0 0] State:[7, array([2, 1, 1, 1, 0, 0]), array([2, 2, 0, 1, 0, 0]), array([18, 20])]
# Score:-692 Action:[3 3 0 0] State:[5, array([2, 1, 1, 1, 0, 0]), array([2, 2, 0, 1, 0, 0]), array([18, 20])]
# Score:-1090 Action:[3 3 0 0] State:[3, array([2, 1, 1, 1, 0, 0]), array([2, 2, 0, 1, 0, 0]), array([18, 20])]
# Score:-1488 Action:[3 3 0 0] State:[1, array([2, 1, 1, 1, 0, 0]), array([2, 2, 0, 1, 0, 0]), array([18, 20])]
# Score:-2086 Action:[3 3 0 0] State:[-1, array([2, 1, 1, 1, 0, 0]), array([2, 2, 0, 1, 0, 0]), array([18, 20])]
