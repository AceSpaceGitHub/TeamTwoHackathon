# %% [markdown]
# 1. Import Dependencies

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env

# %% [markdown]
# # Building an Environment

# %% [markdown]
# Check Training Environment

# %%
import gym
from gym import Env
from gym.spaces import Discrete, Dict, MultiBinary, MultiDiscrete
import numpy as np
import random

class DeterministicScenario:
    def getActionSpace(self):
        return MultiDiscrete([6, 6, 2, 2])
    def getObservationSpace(self):
        return Dict({"missiles": Discrete(100), 
        "expectedShipDamage": MultiDiscrete([100,100,100,100,100,100]), 
        "currentShipDamage": MultiDiscrete([100,100,100,100,100,100]), 
        "target1Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target2Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target3Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target4Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target5Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target6Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target1Targets": MultiBinary(6),
        "target2Targets": MultiBinary(6),
        "target3Targets": MultiBinary(6),
        "target4Targets": MultiBinary(6),
        "target5Targets": MultiBinary(6),
        "target6Targets": MultiBinary(6),
        "assets": MultiDiscrete([100,100])})
    def getRandomizedState(self):
        return {"missiles": random.randint(1, 99),
         "expectedShipDamage": 
         np.array([random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4)]), 
         "currentShipDamage": np.array([0,0,0,0,0,0]),
         "target1Defense": np.array([0,0,25,0,15,0]),
         "target2Defense": np.array([0,0,0,25,0,15]),
         "target3Defense": np.array([0,0,30,0,0,0]),
         "target4Defense": np.array([0,0,0,30,0,0]),
         "target5Defense": np.array([0,0,0,0,40,0]),
         "target6Defense": np.array([0,0,0,0,0,40]),
         "target1Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target2Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target3Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target4Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target5Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "target6Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "assets": np.array([random.randint(1, 99), random.randint(1, 99)])}
    def getState(self, numberOfmissiles, numberOfJets, numberOfPilots, tD1, tD2, tD3, tD4, tD5, tD6):
        return {"missiles": numberOfmissiles,
         "expectedShipDamage": np.array([tD1, tD2, tD3, tD4, tD5, tD6]), 
         "currentShipDamage": np.array([0,0,0,0,0,0]),
         "target1Defense": np.array([0,0,25,0,15,0]),
         "target2Defense": np.array([0,0,0,25,0,15]),
         "target3Defense": np.array([0,0,30,0,0,0]),
         "target4Defense": np.array([0,0,0,30,0,0]),
         "target5Defense": np.array([0,0,0,0,40,0]),
         "target6Defense": np.array([0,0,0,0,0,40]),
         "target1Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target2Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target3Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target4Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target5Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "target6Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "assets": np.array([numberOfJets ,numberOfPilots])}
    def canAttack(self, state, sortiArray, ship1, ship2):
        canAttack = False
        reward = -20
        # Check if can attack
        for sorti in sortiArray:
            if state[sorti][ship1] and state[sorti][ship2]:
                canAttack = True
                reward = 30
                break
        return canAttack, reward
    def shouldAttack(self, state, defenseArray, ship):
        reward = 0
        # Check if ship is already more damaged than expected
        if state["currentShipDamage"][ship] >= state["expectedShipDamage"][ship]:
            # Check to see if target posses a threat
            if(state["currentShipDamage"][ship] == 0 and state[defenseArray[ship]][ship] > 0):
                # Reward for damaging a ship that is a threat?
                reward = 0
            else:
                # no threat and already at expected damage
                reward = -20
        else:
            # targetted a ship worth targetting
            reward = 100
        return reward
    def defendShip(self, state, defenseArray, ship):
        shotDown = False
        length = len(state[defenseArray[ship]])
        for index in range(0, length):
            if(state[defenseArray[ship]][index] > 0):
                roll = random.randint(0,100)
                if(roll <= state[defenseArray[ship]][index]):
                    shotDown = True
        return shotDown
    def shootShip(self, state, defenseArray, ship):
        reward = 0

        state["currentShipDamage"][ship] += 1

        return reward
    def step(self, state, action):
        # Set placeholder for info
        info = {}
        reward = 0
        done = False
        numberOfTargets = 6
        shouldEnd = False
        defenseArray = ["target1Defense", "target2Defense", "target3Defense", "target4Defense", "target5Defense", "target6Defense"]
        sortieArray = ["target1Targets", "target2Targets", "target3Targets", "target4Targets", "target5Targets", "target6Targets"]

        # Should we reward here or after hit or even after checking against expected damage?
        ship1Index = action[0]
        ship2Index = action[1]

        if action[2] == 1:
            reward += 10
        if action[3] == 1:
            reward += 10

        canAttack , canAttackReward = self.canAttack(state, sortieArray, ship1Index, ship2Index)
        reward += canAttackReward
        if canAttack:

            shotDown1 = self.defendShip(state, defenseArray, ship1Index)
            shotDown2 = self.defendShip(state, defenseArray, ship2Index)

            if ship1Index == ship2Index:
                if shotDown1:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1
            else:
                if shotDown1:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1
                if shotDown2:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1

            shouldAttackReward = self.shouldAttack(state, defenseArray, ship1Index)
            reward += shouldAttackReward
            self.shootShip(state, defenseArray, ship1Index)
            state["missiles"] -= 1
            if state["missiles"] == 0:
                shouldEnd = True
            if shouldEnd != True:
                if action[2] == 1:
                    shouldAttackReward = self.shouldAttack(state, defenseArray, ship1Index)
                    reward += shouldAttackReward
                    self.shootShip(state, defenseArray, ship1Index)
                    state["missiles"] -= 1
            if state["missiles"] == 0:
                shouldEnd = True
            if shouldEnd != True:
                shouldAttackReward = self.shouldAttack(state, defenseArray, ship2Index)
                reward += shouldAttackReward
                self.shootShip(state, defenseArray, ship2Index)
                state["missiles"] -= 1
            if state["missiles"] == 0:
                shouldEnd = True
            if shouldEnd != True:
                if action[3] == 1:
                    shouldAttackReward = self.shouldAttack(state, defenseArray, ship2Index)
                    reward += shouldAttackReward
                    self.shootShip(state, defenseArray, ship2Index)
                    state["missiles"] -= 1
        else:
            # Can't attack we are done
            return state, canAttackReward, True, info
        
        # ############# Ideas #################
        # Count up assets instead of down. Add a cap and remove end condition for assets
        # Change Reward/Loss system for expected damage.
        #   Expected damage is now Expected hits. Remove Rolls
        # Add a calculated ratio reward for threats in the defending arrays
        # Add in standard deviation for rewards to encourage spreading out more hits when missles are available.
        #   Prio higher expected hits targets.

        # Add penalty for going over on assets
        if state ["assets"][0] < 0:
            reward -= 200

        if state ["assets"][1] < 0:
            reward -= 200

        isExpectedDamageMet = True
        for shipIndex in range(0, numberOfTargets):
            if state["currentShipDamage"][shipIndex] < state["expectedShipDamage"][shipIndex]:
                isExpectedDamageMet = False
                break

        if isExpectedDamageMet:
            reward += 100
            reward += max(0, state["missiles"])*10
            reward += max(0, state["assets"][0])*5
            reward += max(0, state["assets"][1])*5
            done = True

        if state["missiles"] <= 0:
            done = True

        if state["assets"][0] <= 0 or state["assets"][1] <= 0:
            done = True
        
        # Return step information
        return state, reward, done, info

class DeterministicScenarioEnvironment(Env):
    def __init__(self, numberOfmissiles, numberOfJets, numberOfPilots, tD1, tD2, tD3, tD4, tD5, tD6):
        manager = DeterministicScenario()
        self.manager = manager
        # Actions we can take: 0 - Do Nothing, 1 - Launch
        self.action_space = manager.getActionSpace()
        # Target Damage state array: 0 - Untouched, 1 - Disabled, 2 - Destroyed
        self.observation_space = manager.getObservationSpace()
        # store initial state
        self.numberOfmissiles = numberOfmissiles
        self.numberOfJets = numberOfJets
        self.numberOfPilots = numberOfPilots
        self.tD1 = tD1
        self.tD2 = tD2
        self.tD3 = tD3
        self.tD4 = tD4
        self.tD5 = tD5
        self.tD6 = tD6
        # Set start state
        self.state = self.manager.getState(self.numberOfmissiles, self.numberOfJets, self.numberOfPilots, self.tD1, self.tD2, self.tD3, self.tD4, self.tD5, self.tD6)

    def step(self, action):
        # Return step information
        return self.manager.step(self.state, action)

    def render(self):
        # Implement viz
        pass

    def reset(self):
        # Reset shower temperature
        self.state = self.manager.getState(self.numberOfmissiles, self.numberOfJets, self.numberOfPilots, self.tD1, self.tD2, self.tD3, self.tD4, self.tD5, self.tD6)
        return self.state

class TrainingDeterministicScenarioEnvironment(Env):
    def __init__(self):
        manager = DeterministicScenario()
        self.manager = manager
        # Actions we can take: 0 - Do Nothing, 1 - Launch
        self.action_space = manager.getActionSpace()
        # Target Damage state array: 0 - Untouched, 1 - Disabled, 2 - Destroyed
        self.observation_space = manager.getObservationSpace()
        # Set start state
        self.state = manager.getRandomizedState()

    def step(self, action):
        # Return step information
        return self.manager.step(self.state, action)

    def render(self):
        # Implement viz
        pass

    def reset(self):
        # Reset shower temperature
        self.state = self.manager.getRandomizedState()
        return self.state

# %%
trainingEnv=TrainingDeterministicScenarioEnvironment()
check_env(trainingEnv, warn=True)

# %% [markdown]
# Check Scenario Environment

# %% [markdown]
# # Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
#trainingEnv=TrainingDeterministicScenarioEnvironment()
trainingEnv=TrainingDeterministicScenarioEnvironment()
check_env(trainingEnv, warn=True)
trainingEnv.reset()
model = PPO("MultiInputPolicy", trainingEnv, verbose=1, tensorboard_log=log_path)

# 30ish minute training
#model.learn(total_timesteps=300000*5)

model.learn(total_timesteps=700000*2)

model.save('RandomDeterministicTraining3')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_74
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.53     |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    fps             | 406      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.59        |
# |    ep_rew_mean          | 80.9        |
# | time/                   |             |
# |    fps                  | 318         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008202152 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | -5.44e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.8e+04     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00973    |
# |    value_loss           | 3.31e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.5          |
# |    ep_rew_mean          | 82           |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 3            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0073136603 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 1.19e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.39e+04     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00526     |
# |    value_loss           | 3.66e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.41        |
# |    ep_rew_mean          | 73.1        |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 4           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.020017045 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.93       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.97e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00777    |
# |    value_loss           | 3.93e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.48        |
# |    ep_rew_mean          | 84.4        |
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 5           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009564372 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.9        |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.58e+04    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 3.69e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.47        |
# |    ep_rew_mean          | 88.7        |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 6           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.024614755 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.86       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.53e+04    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 3.92e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51        |
# |    ep_rew_mean          | 83.2        |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 7           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013937522 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.7e+04     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 3.57e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.47        |
# |    ep_rew_mean          | 81.2        |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 8           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.021604955 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.72       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.63e+04    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 4.76e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.55        |
# |    ep_rew_mean          | 128         |
# | time/                   |             |
# |    fps                  | 271         |
# |    iterations           | 9           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.030835407 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.65       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 4.25e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72        |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 10          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.028856605 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.57e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00519    |
# |    value_loss           | 4.62e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62        |
# |    ep_rew_mean          | 114         |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 11          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014803938 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28e+04    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 3.92e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.9         |
# |    ep_rew_mean          | 162         |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 12          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016958326 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86e+04    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 4.61e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 171         |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 13          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011935408 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.84e+04    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 5.42e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.18       |
# |    ep_rew_mean          | 215        |
# | time/                   |            |
# |    fps                  | 268        |
# |    iterations           | 14         |
# |    time_elapsed         | 106        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.43815023 |
# |    clip_fraction        | 0.566      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.89      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.03e+04   |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00225   |
# |    value_loss           | 4.66e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.97       |
# |    ep_rew_mean          | 269        |
# | time/                   |            |
# |    fps                  | 268        |
# |    iterations           | 15         |
# |    time_elapsed         | 114        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.07433772 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.4       |
# |    explained_variance   | 1.79e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.38e+04   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0263    |
# |    value_loss           | 3.9e+04    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.43        |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 16          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.020773027 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.37       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.64e+04    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 4.29e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.63        |
# |    ep_rew_mean          | 326         |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 17          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010544358 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.15e+04    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 4.45e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.61         |
# |    ep_rew_mean          | 347          |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 18           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 8.259647e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.34        |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.77e+04     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 4.4e+04      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.95          |
# |    ep_rew_mean          | 338           |
# | time/                   |               |
# |    fps                  | 267           |
# |    iterations           | 19            |
# |    time_elapsed         | 145           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00028093296 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.34         |
# |    explained_variance   | 0.253         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.62e+04      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.0016       |
# |    value_loss           | 3.77e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.88         |
# |    ep_rew_mean          | 284          |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 20           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0010323196 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.34        |
# |    explained_variance   | 0.251        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.68e+04     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 4.14e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.24        |
# |    ep_rew_mean          | 317         |
# | time/                   |             |
# |    fps                  | 267         |
# |    iterations           | 21          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.002686018 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.264       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.32e+04    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00435    |
# |    value_loss           | 4.2e+04     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.28          |
# |    ep_rew_mean          | 322           |
# | time/                   |               |
# |    fps                  | 267           |
# |    iterations           | 22            |
# |    time_elapsed         | 168           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00045766772 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.37         |
# |    explained_variance   | 0.27          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.12e+04      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.00282      |
# |    value_loss           | 3.83e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.72         |
# |    ep_rew_mean          | 327          |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 23           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0020535905 |
# |    clip_fraction        | 0.000928     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.37        |
# |    explained_variance   | 0.239        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.65e+04     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00413     |
# |    value_loss           | 4.07e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6          |
# |    ep_rew_mean          | 298          |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 24           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0004102121 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.38        |
# |    explained_variance   | 0.205        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.94e+04     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 4.49e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.81         |
# |    ep_rew_mean          | 309          |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 25           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0055117765 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.31        |
# |    explained_variance   | 0.239        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.82e+04     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00429     |
# |    value_loss           | 4.62e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.73         |
# |    ep_rew_mean          | 378          |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 26           |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0031060232 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.32        |
# |    explained_variance   | 0.268        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.14e+04     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00524     |
# |    value_loss           | 3.94e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.14         |
# |    ep_rew_mean          | 347          |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 27           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0020788112 |
# |    clip_fraction        | 0.00488      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.32        |
# |    explained_variance   | 0.258        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.11e+04     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00482     |
# |    value_loss           | 4.75e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.87         |
# |    ep_rew_mean          | 388          |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 28           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0038052807 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.39        |
# |    explained_variance   | 0.269        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78e+04     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00841     |
# |    value_loss           | 4.45e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.33         |
# |    ep_rew_mean          | 343          |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 29           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0032312754 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.35        |
# |    explained_variance   | 0.291        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.52e+04     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00574     |
# |    value_loss           | 4.6e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.43         |
# |    ep_rew_mean          | 381          |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 30           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0032754974 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.39        |
# |    explained_variance   | 0.226        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.14e+04     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00803     |
# |    value_loss           | 4.95e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.85        |
# |    ep_rew_mean          | 407         |
# | time/                   |             |
# |    fps                  | 267         |
# |    iterations           | 31          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.003935335 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.24        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.7e+04     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00688    |
# |    value_loss           | 5.19e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.2         |
# |    ep_rew_mean          | 410         |
# | time/                   |             |
# |    fps                  | 267         |
# |    iterations           | 32          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005149706 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.4        |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.52e+04    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 6.42e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.47         |
# |    ep_rew_mean          | 384          |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 33           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0055470946 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.32        |
# |    explained_variance   | 0.2          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.06e+04     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0131      |
# |    value_loss           | 6.3e+04      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.57        |
# |    ep_rew_mean          | 405         |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 34          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005865814 |
# |    clip_fraction        | 0.0256      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.81e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 5.51e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.45         |
# |    ep_rew_mean          | 451          |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 35           |
# |    time_elapsed         | 267          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0070949746 |
# |    clip_fraction        | 0.0603       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.19        |
# |    explained_variance   | 0.244        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.54e+04     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0149      |
# |    value_loss           | 6.09e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.41         |
# |    ep_rew_mean          | 449          |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 36           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0063578035 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.13        |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.9e+04      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 7.35e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.03        |
# |    ep_rew_mean          | 452         |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 37          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010230155 |
# |    clip_fraction        | 0.0866      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25e+04    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 6.52e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.92         |
# |    ep_rew_mean          | 461          |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 38           |
# |    time_elapsed         | 289          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0072400514 |
# |    clip_fraction        | 0.0411       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.13e+04     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 7.76e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.73        |
# |    ep_rew_mean          | 467         |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 39          |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.009554131 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.53e+04    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 5.97e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.51        |
# |    ep_rew_mean          | 533         |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 40          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007736158 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.352       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.29e+04    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00975    |
# |    value_loss           | 6.59e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.9          |
# |    ep_rew_mean          | 544          |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 41           |
# |    time_elapsed         | 312          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0075458274 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.365        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.53e+04     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 6.55e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.28         |
# |    ep_rew_mean          | 502          |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 42           |
# |    time_elapsed         | 320          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0055000084 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.405        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.8e+04      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00725     |
# |    value_loss           | 6.44e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.25         |
# |    ep_rew_mean          | 569          |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 43           |
# |    time_elapsed         | 327          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0046639815 |
# |    clip_fraction        | 0.0407       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.433        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.46e+04     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0068      |
# |    value_loss           | 6.22e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.87         |
# |    ep_rew_mean          | 554          |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 44           |
# |    time_elapsed         | 335          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0038974013 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.38        |
# |    explained_variance   | 0.459        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.96e+04     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0054      |
# |    value_loss           | 5.74e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.5          |
# |    ep_rew_mean          | 514          |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 45           |
# |    time_elapsed         | 343          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0039277514 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.495        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.18e+04     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00552     |
# |    value_loss           | 5.04e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.33         |
# |    ep_rew_mean          | 588          |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 46           |
# |    time_elapsed         | 350          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0057851537 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | 0.489        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.48e+04     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00843     |
# |    value_loss           | 5.14e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.68        |
# |    ep_rew_mean          | 560         |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 47          |
# |    time_elapsed         | 358         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.008565555 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.39e+04    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00552    |
# |    value_loss           | 5.2e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.68        |
# |    ep_rew_mean          | 526         |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 48          |
# |    time_elapsed         | 366         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009538734 |
# |    clip_fraction        | 0.0483      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.65e+04    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0081     |
# |    value_loss           | 3.98e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.46         |
# |    ep_rew_mean          | 552          |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 49           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0038690497 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 0.482        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.26e+04     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00522     |
# |    value_loss           | 6.22e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.02         |
# |    ep_rew_mean          | 578          |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 50           |
# |    time_elapsed         | 381          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0062390207 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | 0.484        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.98e+04     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00673     |
# |    value_loss           | 5.55e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.88         |
# |    ep_rew_mean          | 603          |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 51           |
# |    time_elapsed         | 389          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0014879921 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0.5          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.3e+04      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 5.19e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.98        |
# |    ep_rew_mean          | 637         |
# | time/                   |             |
# |    fps                  | 267         |
# |    iterations           | 52          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.010169357 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.78e+04    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 4.05e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.2         |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 267         |
# |    iterations           | 53          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.001661554 |
# |    clip_fraction        | 0.00693     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.55e+04    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 7.34e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.6          |
# |    ep_rew_mean          | 642          |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 54           |
# |    time_elapsed         | 413          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0036888672 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.22        |
# |    explained_variance   | 0.527        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.45e+04     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00548     |
# |    value_loss           | 4.95e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.39         |
# |    ep_rew_mean          | 563          |
# | time/                   |              |
# ...
# |    total_timesteps      | 1366016      |
# | train/                  |              |
# |    approx_kl            | 0.0030197515 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0734      |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 272          |
# |    n_updates            | 6660         |
# |    policy_gradient_loss | -0.00349     |
# |    value_loss           | 3.36e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.06        |
# |    ep_rew_mean          | 762         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 668         |
# |    time_elapsed         | 4118        |
# |    total_timesteps      | 1368064     |
# | train/                  |             |
# |    approx_kl            | 0.011942936 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0741     |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 152         |
# |    n_updates            | 6670        |
# |    policy_gradient_loss | -0.00437    |
# |    value_loss           | 2.59e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.62         |
# |    ep_rew_mean          | 834          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 669          |
# |    time_elapsed         | 4124         |
# |    total_timesteps      | 1370112      |
# | train/                  |              |
# |    approx_kl            | 0.0046272874 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0823      |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43e+03     |
# |    n_updates            | 6680         |
# |    policy_gradient_loss | -0.00707     |
# |    value_loss           | 6.91e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.63         |
# |    ep_rew_mean          | 771          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 670          |
# |    time_elapsed         | 4130         |
# |    total_timesteps      | 1372160      |
# | train/                  |              |
# |    approx_kl            | 0.0033142106 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0724      |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 420          |
# |    n_updates            | 6690         |
# |    policy_gradient_loss | -0.0078      |
# |    value_loss           | 7.86e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.23         |
# |    ep_rew_mean          | 884          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 671          |
# |    time_elapsed         | 4135         |
# |    total_timesteps      | 1374208      |
# | train/                  |              |
# |    approx_kl            | 0.0030338597 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.065       |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+03     |
# |    n_updates            | 6700         |
# |    policy_gradient_loss | -0.00729     |
# |    value_loss           | 4.79e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.1          |
# |    ep_rew_mean          | 833          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 672          |
# |    time_elapsed         | 4141         |
# |    total_timesteps      | 1376256      |
# | train/                  |              |
# |    approx_kl            | 0.0060952916 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0592      |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06e+03     |
# |    n_updates            | 6710         |
# |    policy_gradient_loss | -0.00797     |
# |    value_loss           | 6.87e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.14         |
# |    ep_rew_mean          | 776          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 673          |
# |    time_elapsed         | 4147         |
# |    total_timesteps      | 1378304      |
# | train/                  |              |
# |    approx_kl            | 0.0012086013 |
# |    clip_fraction        | 0.00532      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0482      |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 203          |
# |    n_updates            | 6720         |
# |    policy_gradient_loss | -0.0041      |
# |    value_loss           | 3.68e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.93         |
# |    ep_rew_mean          | 784          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 674          |
# |    time_elapsed         | 4152         |
# |    total_timesteps      | 1380352      |
# | train/                  |              |
# |    approx_kl            | 0.0005027633 |
# |    clip_fraction        | 0.00361      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0378      |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 378          |
# |    n_updates            | 6730         |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 4.6e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.32         |
# |    ep_rew_mean          | 846          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 675          |
# |    time_elapsed         | 4158         |
# |    total_timesteps      | 1382400      |
# | train/                  |              |
# |    approx_kl            | 0.0007424668 |
# |    clip_fraction        | 0.00571      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0429      |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 457          |
# |    n_updates            | 6740         |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 5.21e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.09          |
# |    ep_rew_mean          | 803           |
# | time/                   |               |
# |    fps                  | 332           |
# |    iterations           | 676           |
# |    time_elapsed         | 4164          |
# |    total_timesteps      | 1384448       |
# | train/                  |               |
# |    approx_kl            | 0.00038730542 |
# |    clip_fraction        | 0.00649       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.04         |
# |    explained_variance   | 0.972         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 183           |
# |    n_updates            | 6750          |
# |    policy_gradient_loss | -0.000511     |
# |    value_loss           | 3.48e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.96          |
# |    ep_rew_mean          | 846           |
# | time/                   |               |
# |    fps                  | 332           |
# |    iterations           | 677           |
# |    time_elapsed         | 4169          |
# |    total_timesteps      | 1386496       |
# | train/                  |               |
# |    approx_kl            | 0.00020500421 |
# |    clip_fraction        | 0.00288       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0358       |
# |    explained_variance   | 0.971         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 489           |
# |    n_updates            | 6760          |
# |    policy_gradient_loss | -0.0033       |
# |    value_loss           | 3.44e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.12         |
# |    ep_rew_mean          | 858          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 678          |
# |    time_elapsed         | 4175         |
# |    total_timesteps      | 1388544      |
# | train/                  |              |
# |    approx_kl            | 0.0004350186 |
# |    clip_fraction        | 0.00273      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0352      |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 535          |
# |    n_updates            | 6770         |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 3.01e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.25          |
# |    ep_rew_mean          | 831           |
# | time/                   |               |
# |    fps                  | 332           |
# |    iterations           | 679           |
# |    time_elapsed         | 4181          |
# |    total_timesteps      | 1390592       |
# | train/                  |               |
# |    approx_kl            | 0.00056808116 |
# |    clip_fraction        | 0.00864       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0401       |
# |    explained_variance   | 0.964         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.91e+03      |
# |    n_updates            | 6780          |
# |    policy_gradient_loss | 0.00454       |
# |    value_loss           | 5.09e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.12          |
# |    ep_rew_mean          | 887           |
# | time/                   |               |
# |    fps                  | 332           |
# |    iterations           | 680           |
# |    time_elapsed         | 4186          |
# |    total_timesteps      | 1392640       |
# | train/                  |               |
# |    approx_kl            | 0.00051190564 |
# |    clip_fraction        | 0.00254       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0338       |
# |    explained_variance   | 0.969         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.25e+03      |
# |    n_updates            | 6790          |
# |    policy_gradient_loss | -0.00142      |
# |    value_loss           | 4.01e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.12         |
# |    ep_rew_mean          | 818          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 681          |
# |    time_elapsed         | 4192         |
# |    total_timesteps      | 1394688      |
# | train/                  |              |
# |    approx_kl            | 0.0007714798 |
# |    clip_fraction        | 0.0042       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0387      |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 665          |
# |    n_updates            | 6800         |
# |    policy_gradient_loss | -0.0002      |
# |    value_loss           | 4.45e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.21          |
# |    ep_rew_mean          | 789           |
# | time/                   |               |
# |    fps                  | 332           |
# |    iterations           | 682           |
# |    time_elapsed         | 4198          |
# |    total_timesteps      | 1396736       |
# | train/                  |               |
# |    approx_kl            | 0.00043520535 |
# |    clip_fraction        | 0.00273       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0342       |
# |    explained_variance   | 0.972         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 240           |
# |    n_updates            | 6810          |
# |    policy_gradient_loss | -0.00206      |
# |    value_loss           | 3.33e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.23        |
# |    ep_rew_mean          | 859         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 683         |
# |    time_elapsed         | 4204        |
# |    total_timesteps      | 1398784     |
# | train/                  |             |
# |    approx_kl            | 0.002600865 |
# |    clip_fraction        | 0.00918     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.033      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 529         |
# |    n_updates            | 6820        |
# |    policy_gradient_loss | -0.00375    |
# |    value_loss           | 2.61e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.16          |
# |    ep_rew_mean          | 846           |
# | time/                   |               |
# |    fps                  | 332           |
# |    iterations           | 684           |
# |    time_elapsed         | 4209          |
# |    total_timesteps      | 1400832       |
# | train/                  |               |
# |    approx_kl            | 0.00084613677 |
# |    clip_fraction        | 0.00259       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0329       |
# |    explained_variance   | 0.981         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 175           |
# |    n_updates            | 6830          |
# |    policy_gradient_loss | -0.00195      |
# |    value_loss           | 2.21e+03      |
# -------------------------------------------

# %% [markdown]
# # Save Model

# %% [markdown]
# # Evaluate Model

# %%
scenarioEnv.reset()
evaluate_policy(model, scenarioEnv, n_eval_episodes=10000, render=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12128/3146449017.py in <module>
# ----> 1 scenarioEnv.reset()
#       2 evaluate_policy(model, scenarioEnv, n_eval_episodes=10000, render=False)
#
# NameError: name 'scenarioEnv' is not defined

# %%
scenarioEnv = DeterministicScenarioEnvironment(13, 19, 21, 4, 2, 2, 2, 0, 0)
sampleEnvObs = scenarioEnv.reset()
done = False
score = 0 

while not done:
    action, _ = model.predict(sampleEnvObs)
    sampleEnvObs, reward, done, info = scenarioEnv.step(action)
    score+=reward
    print('Score:{} Action:{} State:{}'.format(score, action, [sampleEnvObs["missiles"],sampleEnvObs["expectedShipDamage"], sampleEnvObs["currentShipDamage"], sampleEnvObs["assets"]]))
scenarioEnv.close()
# Out:
# Score:450 Action:[1 3 1 1] State:[9, array([4, 2, 2, 2, 0, 0]), array([0, 2, 0, 2, 0, 0]), array([18, 20])]
# Score:460 Action:[5 4 1 1] State:[5, array([4, 2, 2, 2, 0, 0]), array([0, 2, 0, 2, 2, 2]), array([18, 20])]
# Score:430 Action:[5 4 1 1] State:[1, array([4, 2, 2, 2, 0, 0]), array([0, 2, 0, 2, 4, 4]), array([17, 19])]
# Score:410 Action:[5 3 1 1] State:[1, array([4, 2, 2, 2, 0, 0]), array([0, 2, 0, 2, 4, 4]), array([17, 19])]
