# %% [markdown]
# 1. Import Dependencies

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env

# %% [markdown]
# # Building an Environment

# %% [markdown]
# Check Training Environment

# %%
import gym
from gym import Env
from gym.spaces import Discrete, Dict, MultiBinary, MultiDiscrete
import numpy as np
import random

class DeterministicScenario:
    def getActionSpace(self):
        return MultiDiscrete([6, 6, 2, 2])
    def getObservationSpace(self):
        return Dict({"missiles": Discrete(100), 
        "expectedShipDamage": MultiDiscrete([100,100,100,100,100,100]), 
        "currentShipDamage": MultiDiscrete([100,100,100,100,100,100]), 
        "target1Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target2Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target3Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target4Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target5Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target6Defense": MultiDiscrete([100,100,100,100,100,100]),
        "target1Targets": MultiBinary(6),
        "target2Targets": MultiBinary(6),
        "target3Targets": MultiBinary(6),
        "target4Targets": MultiBinary(6),
        "target5Targets": MultiBinary(6),
        "target6Targets": MultiBinary(6),
        "assets": MultiDiscrete([100,100])})
    def getRandomizedState(self):
        return {"missiles": random.randint(1, 99),
         "expectedShipDamage": 
         np.array([random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4), 
         random.randint(0, 4)]), 
         "currentShipDamage": np.array([0,0,0,0,0,0]),
         "target1Defense": np.array([0,0,25,0,15,0]),
         "target2Defense": np.array([0,0,0,25,0,15]),
         "target3Defense": np.array([0,0,30,0,0,0]),
         "target4Defense": np.array([0,0,0,30,0,0]),
         "target5Defense": np.array([0,0,0,0,40,0]),
         "target6Defense": np.array([0,0,0,0,0,40]),
         "target1Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target2Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target3Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target4Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target5Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "target6Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "assets": np.array([random.randint(1, 99), random.randint(1, 99)])}
    def getState(self, numberOfmissiles, numberOfJets, numberOfPilots, tD1, tD2, tD3, tD4, tD5, tD6):
        return {"missiles": numberOfmissiles,
         "expectedShipDamage": np.array([tD1, tD2, tD3, tD4, tD5, tD6]), 
         "currentShipDamage": np.array([0,0,0,0,0,0]),
         "target1Defense": np.array([0,0,25,0,15,0]),
         "target2Defense": np.array([0,0,0,25,0,15]),
         "target3Defense": np.array([0,0,30,0,0,0]),
         "target4Defense": np.array([0,0,0,30,0,0]),
         "target5Defense": np.array([0,0,0,0,40,0]),
         "target6Defense": np.array([0,0,0,0,0,40]),
         "target1Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target2Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target3Targets": np.array([1, 0, 1, 0 , 0, 0]),
         "target4Targets": np.array([0, 1, 0, 1 , 0, 0]),
         "target5Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "target6Targets": np.array([0, 0, 0, 0 , 1, 1]),
         "assets": np.array([numberOfJets ,numberOfPilots])}
    def canAttack(self, state, sortiArray, ship1, ship2):
        canAttack = False
        reward = -1000
        # Check if can attack
        for sorti in sortiArray:
            if state[sorti][ship1] and state[sorti][ship2]:
                canAttack = True
                reward = 20
                break
        return canAttack, reward
    def shouldAttack(self, state, defenseArray, ship):
        reward = 0
        shouldAttack = True
        # Check if ship is already more damaged than expected
        if state["currentShipDamage"][ship] >= state["expectedShipDamage"][ship]:
            # Check to see if target posses a threat
            if(state["currentShipDamage"][ship] == 0 and state[defenseArray[ship]][ship] > 0):
                # Reward for damaging a ship that is a threat?
                reward = 0
            else:
                # no threat and already at expected damage
                reward = -200
                shouldAttack = False
        else:
            # targetted a ship worth targetting
            reward = 100
        return shouldAttack, reward
    def defendShip(self, state, defenseArray, ship):
        shotDown = False
        length = len(state[defenseArray[ship]])
        for index in range(0, length):
            if(state[defenseArray[ship]][index] > 0):
                roll = random.randint(0,100)
                if(roll <= state[defenseArray[ship]][index]):
                    shotDown = True
        return shotDown
    def shootShip(self, state, defenseArray, ship):
        reward = 0

        state["currentShipDamage"][ship] += 1

        return reward
    def step(self, state, action):
        # Set placeholder for info
        info = {}
        reward = 0
        done = False
        numberOfTargets = 6
        defenseArray = ["target1Defense", "target2Defense", "target3Defense", "target4Defense", "target5Defense", "target6Defense"]
        sortieArray = ["target1Targets", "target2Targets", "target3Targets", "target4Targets", "target5Targets", "target6Targets"]

        # Should we reward here or after hit or even after checking against expected damage?
        ship1Index = action[0]
        ship2Index = action[1]

        if action[2] == 1:
            reward += 10
        if action[3] == 1:
            reward += 10

        canAttack , canAttackReward = self.canAttack(state, sortieArray, ship1Index, ship2Index)
        reward += canAttackReward
        if canAttack:

            shotDown1 = self.defendShip(state, defenseArray, ship1Index)
            shotDown2 = self.defendShip(state, defenseArray, ship2Index)

            if ship1Index == ship2Index:
                if shotDown1:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1
            else:
                if shotDown1:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1
                if shotDown2:
                    state["assets"][0] -= 1
                    state["assets"][1] -= 1

            shouldAttack, shouldAttackReward = self.shouldAttack(state, defenseArray, ship1Index)
            reward += shouldAttackReward
            self.shootShip(state, defenseArray, ship1Index)
            state["missiles"] -= 1
            if action[2] == 1:
                shouldAttack, shouldAttackReward = self.shouldAttack(state, defenseArray, ship1Index)
                reward += shouldAttackReward
                self.shootShip(state, defenseArray, ship1Index)
                state["missiles"] -= 1
            shouldAttack, shouldAttackReward = self.shouldAttack(state, defenseArray, ship2Index)
            reward += shouldAttackReward
            self.shootShip(state, defenseArray, ship2Index)
            state["missiles"] -= 1
            if action[3] == 1:
                shouldAttack, shouldAttackReward = self.shouldAttack(state, defenseArray, ship2Index)
                reward += shouldAttackReward
                self.shootShip(state, defenseArray, ship2Index)
                state["missiles"] -= 1
        else:
            # Can't attack we are done
            return state, canAttackReward, False, info
        
        # ############# Ideas #################
        # Count up assets instead of down. Add a cap and remove end condition for assets
        # Change Reward/Loss system for expected damage.
        #   Expected damage is now Expected hits. Remove Rolls
        # Add a calculated ratio reward for threats in the defending arrays
        # Add in standard deviation for rewards to encourage spreading out more hits when missles are available.
        #   Prio higher expected hits targets.

        # Add penalty for going over on assets
        if state["missiles"] < 0:
            reward -= 2000

        if state ["assets"][0] < 0:
            reward -= 200

        if state ["assets"][1] < 0:
            reward -= 200

        isExpectedDamageMet = True
        for shipIndex in range(0, numberOfTargets):
            if state["currentShipDamage"][shipIndex] < state["expectedShipDamage"][shipIndex]:
                isExpectedDamageMet = False
                break

        if isExpectedDamageMet:
            reward += 100
            reward += max(0, state["missiles"])*10
            reward += max(0, state["assets"][0])*5
            reward += max(0, state["assets"][1])*5
            done = True

        if state["missiles"] <= 0:
            done = True

        if state["assets"][0] <= 0 or state["assets"][1] <= 0:
            done = True
        
        # Return step information
        return state, reward, done, info

class DeterministicScenarioEnvironment(Env):
    def __init__(self, numberOfmissiles, numberOfJets, numberOfPilots, tD1, tD2, tD3, tD4, tD5, tD6):
        manager = DeterministicScenario()
        self.manager = manager
        # Actions we can take: 0 - Do Nothing, 1 - Launch
        self.action_space = manager.getActionSpace()
        # Target Damage state array: 0 - Untouched, 1 - Disabled, 2 - Destroyed
        self.observation_space = manager.getObservationSpace()
        # store initial state
        self.numberOfmissiles = numberOfmissiles
        self.numberOfJets = numberOfJets
        self.numberOfPilots = numberOfPilots
        self.tD1 = tD1
        self.tD2 = tD2
        self.tD3 = tD3
        self.tD4 = tD4
        self.tD5 = tD5
        self.tD6 = tD6
        # Set start state
        self.state = self.manager.getState(self.numberOfmissiles, self.numberOfJets, self.numberOfPilots, self.tD1, self.tD2, self.tD3, self.tD4, self.tD5, self.tD6)

    def step(self, action):
        # Return step information
        return self.manager.step(self.state, action)

    def render(self):
        # Implement viz
        pass

    def reset(self):
        # Reset shower temperature
        self.state = self.manager.getState(self.numberOfmissiles, self.numberOfJets, self.numberOfPilots, self.tD1, self.tD2, self.tD3, self.tD4, self.tD5, self.tD6)
        return self.state

class TrainingDeterministicScenarioEnvironment(Env):
    def __init__(self):
        manager = DeterministicScenario()
        self.manager = manager
        # Actions we can take: 0 - Do Nothing, 1 - Launch
        self.action_space = manager.getActionSpace()
        # Target Damage state array: 0 - Untouched, 1 - Disabled, 2 - Destroyed
        self.observation_space = manager.getObservationSpace()
        # Set start state
        self.state = manager.getRandomizedState()

    def step(self, action):
        # Return step information
        return self.manager.step(self.state, action)

    def render(self):
        # Implement viz
        pass

    def reset(self):
        # Reset shower temperature
        self.state = self.manager.getRandomizedState()
        return self.state

# %% [markdown]
# Check Scenario Environment

# %% [markdown]
# # Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
#trainingEnv=DeterministicScenarioEnvironment(13, 19, 21, 4, 2, 2, 2, 0, 0)
trainingEnv=TrainingDeterministicScenarioEnvironment()
check_env(trainingEnv, warn=True)
trainingEnv.reset()
model = PPO("MultiInputPolicy", trainingEnv, verbose=1, tensorboard_log=log_path)

# 30ish minute training
#model.learn(total_timesteps=300000*5)

#model.learn(total_timesteps=700000*2)

model.learn(total_timesteps=150000*2*4)

model.save('RandomDeterministicTraining3')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_90
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 29.7      |
# |    ep_rew_mean     | -2.19e+04 |
# | time/              |           |
# |    fps             | 530       |
# |    iterations      | 1         |
# |    time_elapsed    | 3         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.9         |
# |    ep_rew_mean          | -2.12e+04    |
# | time/                   |              |
# |    fps                  | 442          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 7.202296e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 2.62e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.38e+07     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000102    |
# |    value_loss           | 7.12e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -2.27e+04   |
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 4.96392e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.32e+07    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.000123   |
# |    value_loss           | 7.25e+07    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 32.6          |
# |    ep_rew_mean          | -2.48e+04     |
# | time/                   |               |
# |    fps                  | 411           |
# |    iterations           | 4             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.0589807e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.79e+07      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000241     |
# |    value_loss           | 8.13e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.8         |
# |    ep_rew_mean          | -2.31e+04    |
# | time/                   |              |
# |    fps                  | 404          |
# |    iterations           | 5            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 8.128816e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.6e+07      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000188    |
# |    value_loss           | 7.75e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.6         |
# |    ep_rew_mean          | -2.37e+04    |
# | time/                   |              |
# |    fps                  | 398          |
# |    iterations           | 6            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 4.909263e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.98e+07     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00014     |
# |    value_loss           | 7.6e+07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.3         |
# |    ep_rew_mean          | -2.29e+04    |
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 7            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 6.689981e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.95e+07     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000124    |
# |    value_loss           | 8.19e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.3          |
# |    ep_rew_mean          | -1.91e+04     |
# | time/                   |               |
# |    fps                  | 393           |
# |    iterations           | 8             |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 2.1706277e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.95e+07      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000313     |
# |    value_loss           | 7.8e+07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.6          |
# |    ep_rew_mean          | -2.11e+04     |
# | time/                   |               |
# |    fps                  | 392           |
# |    iterations           | 9             |
# |    time_elapsed         | 47            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 5.7749567e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.2e+07       |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000137     |
# |    value_loss           | 6.13e+07      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 25.9           |
# |    ep_rew_mean          | -1.93e+04      |
# | time/                   |                |
# |    fps                  | 390            |
# |    iterations           | 10             |
# |    time_elapsed         | 52             |
# |    total_timesteps      | 20480          |
# | train/                  |                |
# |    approx_kl            | 1.32101995e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -4.97          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.8e+07        |
# |    n_updates            | 90             |
# |    policy_gradient_loss | -0.000247      |
# |    value_loss           | 7.53e+07       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29            |
# |    ep_rew_mean          | -2.19e+04     |
# | time/                   |               |
# |    fps                  | 389           |
# |    iterations           | 11            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.3740209e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.16e+07      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -5.34e-05     |
# |    value_loss           | 6.76e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29.7          |
# |    ep_rew_mean          | -2.25e+04     |
# | time/                   |               |
# |    fps                  | 388           |
# |    iterations           | 12            |
# |    time_elapsed         | 63            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 4.7759095e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.87e+07      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000125     |
# |    value_loss           | 7.89e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28            |
# |    ep_rew_mean          | -2.13e+04     |
# | time/                   |               |
# |    fps                  | 387           |
# |    iterations           | 13            |
# |    time_elapsed         | 68            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.1128868e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.38e+07      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000277     |
# |    value_loss           | 7.69e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 31.4          |
# |    ep_rew_mean          | -2.4e+04      |
# | time/                   |               |
# |    fps                  | 386           |
# |    iterations           | 14            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 1.1165801e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.97e+07      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000205     |
# |    value_loss           | 7.63e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 30.6          |
# |    ep_rew_mean          | -2.3e+04      |
# | time/                   |               |
# |    fps                  | 385           |
# |    iterations           | 15            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 1.1928001e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.27e+07      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000218     |
# |    value_loss           | 8.62e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.5         |
# |    ep_rew_mean          | -2.19e+04    |
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 16           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 7.657247e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.25e+07     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000149    |
# |    value_loss           | 7.5e+07      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29.6          |
# |    ep_rew_mean          | -2.21e+04     |
# | time/                   |               |
# |    fps                  | 384           |
# |    iterations           | 17            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 4.3560576e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.05e+07      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -9.31e-05     |
# |    value_loss           | 6.71e+07      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 29.6           |
# |    ep_rew_mean          | -2.24e+04      |
# | time/                   |                |
# |    fps                  | 384            |
# |    iterations           | 18             |
# |    time_elapsed         | 95             |
# |    total_timesteps      | 36864          |
# | train/                  |                |
# |    approx_kl            | 1.04778155e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -4.97          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 4.69e+07       |
# |    n_updates            | 170            |
# |    policy_gradient_loss | -0.000183      |
# |    value_loss           | 8.19e+07       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.9          |
# |    ep_rew_mean          | -2.22e+04     |
# | time/                   |               |
# |    fps                  | 383           |
# |    iterations           | 19            |
# |    time_elapsed         | 101           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 6.9737725e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.79e+07      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000119     |
# |    value_loss           | 7.77e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.6         |
# |    ep_rew_mean          | -2.01e+04    |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 20           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 7.702038e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.2e+07      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000133    |
# |    value_loss           | 7.1e+07      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.5          |
# |    ep_rew_mean          | -2.06e+04     |
# | time/                   |               |
# |    fps                  | 383           |
# |    iterations           | 21            |
# |    time_elapsed         | 112           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 1.2180564e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.57e+07      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.00021      |
# |    value_loss           | 7.18e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.5         |
# |    ep_rew_mean          | -2.03e+04    |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 22           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 8.457078e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.56e+07     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000167    |
# |    value_loss           | 7.43e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29.1          |
# |    ep_rew_mean          | -2.19e+04     |
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 23            |
# |    time_elapsed         | 123           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 3.5416451e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.21e+07      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000121     |
# |    value_loss           | 7.26e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.1         |
# |    ep_rew_mean          | -2.35e+04    |
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 24           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 5.884416e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.84e+07     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000109    |
# |    value_loss           | 7.62e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 31.4          |
# |    ep_rew_mean          | -2.34e+04     |
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 25            |
# |    time_elapsed         | 134           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 5.6600547e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.19e+07      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000123     |
# |    value_loss           | 8.26e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 31.6          |
# |    ep_rew_mean          | -2.41e+04     |
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 26            |
# |    time_elapsed         | 139           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 4.4154585e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.54e+07      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000114     |
# |    value_loss           | 7.49e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.9          |
# |    ep_rew_mean          | -1.85e+04     |
# | time/                   |               |
# |    fps                  | 380           |
# |    iterations           | 27            |
# |    time_elapsed         | 145           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.2584816e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.13e+07      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000286     |
# |    value_loss           | 8.38e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28            |
# |    ep_rew_mean          | -2.07e+04     |
# | time/                   |               |
# |    fps                  | 380           |
# |    iterations           | 28            |
# |    time_elapsed         | 150           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 1.0792603e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.13e+07      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000216     |
# |    value_loss           | 6.76e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 30.4          |
# |    ep_rew_mean          | -2.26e+04     |
# | time/                   |               |
# |    fps                  | 380           |
# |    iterations           | 29            |
# |    time_elapsed         | 156           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 1.1056516e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.47e+07      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000143     |
# |    value_loss           | 7.08e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.9         |
# |    ep_rew_mean          | -2.23e+04    |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 30           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 9.856012e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.87e+07     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000157    |
# |    value_loss           | 7.48e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.4          |
# |    ep_rew_mean          | -2.09e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 31            |
# |    time_elapsed         | 167           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 1.9550498e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.36e+07      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -5.83e-05     |
# |    value_loss           | 7.37e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.6         |
# |    ep_rew_mean          | -2.18e+04    |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 32           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 9.124575e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.31e+07     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000172    |
# |    value_loss           | 8.06e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.5         |
# |    ep_rew_mean          | -2.22e+04    |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 33           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 9.524141e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.49e+07     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000156    |
# |    value_loss           | 7.21e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29.5          |
# |    ep_rew_mean          | -2.22e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 34            |
# |    time_elapsed         | 183           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 1.3836398e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.81e+07      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000191     |
# |    value_loss           | 7.54e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.7          |
# |    ep_rew_mean          | -2.05e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 35            |
# |    time_elapsed         | 188           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 3.8231956e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.1e+07       |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.000128     |
# |    value_loss           | 7.27e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.2          |
# |    ep_rew_mean          | -2.12e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 36            |
# |    time_elapsed         | 194           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 1.0112271e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.56e+07      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000173     |
# |    value_loss           | 7.03e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29.5          |
# |    ep_rew_mean          | -2.23e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 37            |
# |    time_elapsed         | 199           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 7.2529947e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.93e+07      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.00013      |
# |    value_loss           | 7.22e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.9         |
# |    ep_rew_mean          | -2.25e+04    |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 38           |
# |    time_elapsed         | 205          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 8.509873e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.75e+07     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000139    |
# |    value_loss           | 7.4e+07      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.2          |
# |    ep_rew_mean          | -2.04e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 39            |
# |    time_elapsed         | 210           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 5.9769955e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.8e+07       |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000146     |
# |    value_loss           | 7.46e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.5         |
# |    ep_rew_mean          | -2.14e+04    |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 40           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 4.616799e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.8e+07      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000103    |
# |    value_loss           | 6.94e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 30            |
# |    ep_rew_mean          | -2.27e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 41            |
# |    time_elapsed         | 221           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 1.3040059e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.41e+07      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000174     |
# |    value_loss           | 6.9e+07       |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.2       |
# |    ep_rew_mean          | -2.3e+04   |
# | time/                   |            |
# |    fps                  | 379        |
# |    iterations           | 42         |
# |    time_elapsed         | 226        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 5.3283e-06 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.97      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.87e+07   |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.000132  |
# |    value_loss           | 7.76e+07   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29.1          |
# |    ep_rew_mean          | -2.21e+04     |
# | time/                   |               |
# |    fps                  | 378           |
# |    iterations           | 43            |
# |    time_elapsed         | 232           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 2.6245194e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.88e+07      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000365     |
# |    value_loss           | 7.55e+07      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.7        |
# |    ep_rew_mean          | -1.96e+04   |
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 44          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 7.00535e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.18e+07    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.000128   |
# |    value_loss           | 7.38e+07    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29.5          |
# |    ep_rew_mean          | -2.19e+04     |
# | time/                   |               |
# |    fps                  | 378           |
# |    iterations           | 45            |
# |    time_elapsed         | 243           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 5.5870623e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.76e+07      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000135     |
# |    value_loss           | 7e+07         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 30.8          |
# |    ep_rew_mean          | -2.33e+04     |
# | time/                   |               |
# |    fps                  | 378           |
# |    iterations           | 46            |
# |    time_elapsed         | 248           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 1.2637553e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.38e+07      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000181     |
# |    value_loss           | 7.33e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.1         |
# |    ep_rew_mean          | -2.1e+04     |
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 47           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 5.525304e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.41e+07     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000122    |
# |    value_loss           | 8.23e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.7         |
# |    ep_rew_mean          | -2.22e+04    |
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 48           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 9.231473e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.07e+07     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000155    |
# |    value_loss           | 6.85e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.6          |
# |    ep_rew_mean          | -1.97e+04     |
# | time/                   |               |
# |    fps                  | 378           |
# |    iterations           | 49            |
# |    time_elapsed         | 265           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 4.2595493e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.67e+07      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -8.39e-05     |
# |    value_loss           | 7.29e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.3         |
# |    ep_rew_mean          | -1.87e+04    |
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 50           |
# |    time_elapsed         | 270          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 8.598552e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.92e+07     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000192    |
# |    value_loss           | 6.82e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.1         |
# |    ep_rew_mean          | -2.08e+04    |
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 51           |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 9.867566e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.88e+07     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000138    |
# |    value_loss           | 7.13e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.7          |
# |    ep_rew_mean          | -1.99e+04     |
# | time/                   |               |
# |    fps                  | 378           |
# |    iterations           | 52            |
# |    time_elapsed         | 281           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 1.4797522e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.67e+07      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000189     |
# |    value_loss           | 7.06e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29.6          |
# |    ep_rew_mean          | -2.22e+04     |
# | time/                   |               |
# |    fps                  | 377           |
# |    iterations           | 53            |
# |    time_elapsed         | 287           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 3.3012766e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.57e+07      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -8.99e-05     |
# ...
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.63         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.69e+07      |
# |    n_updates            | 5680          |
# |    policy_gradient_loss | -0.000758     |
# |    value_loss           | 5.46e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.3          |
# |    ep_rew_mean          | -2.11e+04     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 570           |
# |    time_elapsed         | 3101          |
# |    total_timesteps      | 1167360       |
# | train/                  |               |
# |    approx_kl            | 0.00017705408 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.64         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.37e+07      |
# |    n_updates            | 5690          |
# |    policy_gradient_loss | -0.000644     |
# |    value_loss           | 5.23e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.4          |
# |    ep_rew_mean          | -2.15e+04     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 571           |
# |    time_elapsed         | 3107          |
# |    total_timesteps      | 1169408       |
# | train/                  |               |
# |    approx_kl            | 0.00025581184 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.64         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.94e+07      |
# |    n_updates            | 5700          |
# |    policy_gradient_loss | -0.000908     |
# |    value_loss           | 5.62e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.6          |
# |    ep_rew_mean          | -2.08e+04     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 572           |
# |    time_elapsed         | 3112          |
# |    total_timesteps      | 1171456       |
# | train/                  |               |
# |    approx_kl            | 7.5775635e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.63         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.93e+07      |
# |    n_updates            | 5710          |
# |    policy_gradient_loss | -0.000357     |
# |    value_loss           | 5.84e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.6         |
# |    ep_rew_mean          | -2.09e+04    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 573          |
# |    time_elapsed         | 3117         |
# |    total_timesteps      | 1173504      |
# | train/                  |              |
# |    approx_kl            | 6.746678e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.63        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.82e+07     |
# |    n_updates            | 5720         |
# |    policy_gradient_loss | -0.000414    |
# |    value_loss           | 5.63e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.7          |
# |    ep_rew_mean          | -1.9e+04      |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 574           |
# |    time_elapsed         | 3123          |
# |    total_timesteps      | 1175552       |
# | train/                  |               |
# |    approx_kl            | 0.00020088966 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.62         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.39e+07      |
# |    n_updates            | 5730          |
# |    policy_gradient_loss | -0.000615     |
# |    value_loss           | 5.37e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.4          |
# |    ep_rew_mean          | -2.06e+04     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 575           |
# |    time_elapsed         | 3128          |
# |    total_timesteps      | 1177600       |
# | train/                  |               |
# |    approx_kl            | 0.00019650618 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.61         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.07e+07      |
# |    n_updates            | 5740          |
# |    policy_gradient_loss | -0.00101      |
# |    value_loss           | 5.36e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.9          |
# |    ep_rew_mean          | -2.19e+04     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 576           |
# |    time_elapsed         | 3134          |
# |    total_timesteps      | 1179648       |
# | train/                  |               |
# |    approx_kl            | 0.00011363148 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.62         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.7e+07       |
# |    n_updates            | 5750          |
# |    policy_gradient_loss | -0.000478     |
# |    value_loss           | 6.33e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.9          |
# |    ep_rew_mean          | -2.12e+04     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 577           |
# |    time_elapsed         | 3139          |
# |    total_timesteps      | 1181696       |
# | train/                  |               |
# |    approx_kl            | 4.9225113e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.62         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.06e+07      |
# |    n_updates            | 5760          |
# |    policy_gradient_loss | -0.000211     |
# |    value_loss           | 6.28e+07      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.6        |
# |    ep_rew_mean          | -1.99e+04   |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 578         |
# |    time_elapsed         | 3145        |
# |    total_timesteps      | 1183744     |
# | train/                  |             |
# |    approx_kl            | 8.01791e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.15e+07    |
# |    n_updates            | 5770        |
# |    policy_gradient_loss | -0.000442   |
# |    value_loss           | 6.05e+07    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.9          |
# |    ep_rew_mean          | -2.19e+04     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 579           |
# |    time_elapsed         | 3150          |
# |    total_timesteps      | 1185792       |
# | train/                  |               |
# |    approx_kl            | 0.00020484472 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.61         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.71e+07      |
# |    n_updates            | 5780          |
# |    policy_gradient_loss | -0.000873     |
# |    value_loss           | 5.72e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.1          |
# |    ep_rew_mean          | -2.02e+04     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 580           |
# |    time_elapsed         | 3155          |
# |    total_timesteps      | 1187840       |
# | train/                  |               |
# |    approx_kl            | 4.6681118e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.61         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.74e+07      |
# |    n_updates            | 5790          |
# |    policy_gradient_loss | -0.000281     |
# |    value_loss           | 6.28e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25            |
# |    ep_rew_mean          | -1.93e+04     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 581           |
# |    time_elapsed         | 3161          |
# |    total_timesteps      | 1189888       |
# | train/                  |               |
# |    approx_kl            | 0.00025558076 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.61         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.46e+07      |
# |    n_updates            | 5800          |
# |    policy_gradient_loss | -0.000974     |
# |    value_loss           | 5.26e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.8         |
# |    ep_rew_mean          | -2.13e+04    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 582          |
# |    time_elapsed         | 3166         |
# |    total_timesteps      | 1191936      |
# | train/                  |              |
# |    approx_kl            | 8.877582e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.62        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.8e+07      |
# |    n_updates            | 5810         |
# |    policy_gradient_loss | -0.000407    |
# |    value_loss           | 5e+07        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.5         |
# |    ep_rew_mean          | -1.99e+04    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 583          |
# |    time_elapsed         | 3172         |
# |    total_timesteps      | 1193984      |
# | train/                  |              |
# |    approx_kl            | 8.225342e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.62        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.98e+07     |
# |    n_updates            | 5820         |
# |    policy_gradient_loss | -0.000506    |
# |    value_loss           | 6.4e+07      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.8          |
# |    ep_rew_mean          | -2.12e+04     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 584           |
# |    time_elapsed         | 3177          |
# |    total_timesteps      | 1196032       |
# | train/                  |               |
# |    approx_kl            | 0.00019776673 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.62         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.5e+07       |
# |    n_updates            | 5830          |
# |    policy_gradient_loss | -0.000613     |
# |    value_loss           | 4.99e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26           |
# |    ep_rew_mean          | -2.02e+04    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 585          |
# |    time_elapsed         | 3183         |
# |    total_timesteps      | 1198080      |
# | train/                  |              |
# |    approx_kl            | 5.202199e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.61        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.35e+07     |
# |    n_updates            | 5840         |
# |    policy_gradient_loss | -0.000329    |
# |    value_loss           | 6.43e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.2          |
# |    ep_rew_mean          | -2.14e+04     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 586           |
# |    time_elapsed         | 3188          |
# |    total_timesteps      | 1200128       |
# | train/                  |               |
# |    approx_kl            | 0.00026294775 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.62         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.43e+07      |
# |    n_updates            | 5850          |
# |    policy_gradient_loss | -0.000835     |
# |    value_loss           | 5.9e+07       |
# -------------------------------------------

# %%
model.learn(total_timesteps=150000*2*4)

model.save('RandomDeterministicTraining3')
# Out:
# Logging to Training\Logs\PPO_91
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.2     |
# |    ep_rew_mean     | -2e+04   |
# | time/              |          |
# |    fps             | 768      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25           |
# |    ep_rew_mean          | -1.95e+04    |
# | time/                   |              |
# |    fps                  | 502          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 8.694321e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.62        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.6e+07      |
# |    n_updates            | 5870         |
# |    policy_gradient_loss | -0.000539    |
# |    value_loss           | 6.17e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 22.9          |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 451           |
# |    iterations           | 3             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00022998679 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.61         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.13e+07      |
# |    n_updates            | 5880          |
# |    policy_gradient_loss | -0.000682     |
# |    value_loss           | 5.2e+07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 23.9          |
# |    ep_rew_mean          | -1.84e+04     |
# | time/                   |               |
# |    fps                  | 431           |
# |    iterations           | 4             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 7.9176854e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.6          |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.07e+07      |
# |    n_updates            | 5890          |
# |    policy_gradient_loss | -0.000402     |
# |    value_loss           | 4.91e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.9          |
# |    ep_rew_mean          | -2.02e+04     |
# | time/                   |               |
# |    fps                  | 419           |
# |    iterations           | 5             |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 2.5840243e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.6          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.88e+07      |
# |    n_updates            | 5900          |
# |    policy_gradient_loss | -0.000117     |
# |    value_loss           | 5.04e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29            |
# |    ep_rew_mean          | -2.31e+04     |
# | time/                   |               |
# |    fps                  | 412           |
# |    iterations           | 6             |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 3.6966405e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.6          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.75e+07      |
# |    n_updates            | 5910          |
# |    policy_gradient_loss | -0.00024      |
# |    value_loss           | 6.52e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.5          |
# |    ep_rew_mean          | -1.9e+04      |
# | time/                   |               |
# |    fps                  | 406           |
# |    iterations           | 7             |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00013609199 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.59         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.14e+07      |
# |    n_updates            | 5920          |
# |    policy_gradient_loss | -0.000492     |
# |    value_loss           | 6.19e+07      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 26.6           |
# |    ep_rew_mean          | -2.07e+04      |
# | time/                   |                |
# |    fps                  | 402            |
# |    iterations           | 8              |
# |    time_elapsed         | 40             |
# |    total_timesteps      | 16384          |
# | train/                  |                |
# |    approx_kl            | 0.000102072896 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -4.59          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.18e+07       |
# |    n_updates            | 5930           |
# |    policy_gradient_loss | -0.000497      |
# |    value_loss           | 4.96e+07       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26            |
# |    ep_rew_mean          | -2.01e+04     |
# | time/                   |               |
# |    fps                  | 399           |
# |    iterations           | 9             |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 1.9423518e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.59         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.78e+07      |
# |    n_updates            | 5940          |
# |    policy_gradient_loss | -0.000115     |
# |    value_loss           | 5.83e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 23            |
# |    ep_rew_mean          | -1.74e+04     |
# | time/                   |               |
# |    fps                  | 397           |
# |    iterations           | 10            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00019690458 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.59         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.38e+07      |
# |    n_updates            | 5950          |
# |    policy_gradient_loss | -0.00097      |
# |    value_loss           | 5.3e+07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.2          |
# |    ep_rew_mean          | -1.94e+04     |
# | time/                   |               |
# |    fps                  | 395           |
# |    iterations           | 11            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 6.0094317e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.58         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.51e+07      |
# |    n_updates            | 5960          |
# |    policy_gradient_loss | -0.000207     |
# |    value_loss           | 4.72e+07      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 26.9           |
# |    ep_rew_mean          | -2.09e+04      |
# | time/                   |                |
# |    fps                  | 393            |
# |    iterations           | 12             |
# |    time_elapsed         | 62             |
# |    total_timesteps      | 24576          |
# | train/                  |                |
# |    approx_kl            | 0.000111775356 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -4.58          |
# |    explained_variance   | 1.79e-07       |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.75e+07       |
# |    n_updates            | 5970           |
# |    policy_gradient_loss | -0.000495      |
# |    value_loss           | 4.99e+07       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 22.2          |
# |    ep_rew_mean          | -1.72e+04     |
# | time/                   |               |
# |    fps                  | 392           |
# |    iterations           | 13            |
# |    time_elapsed         | 67            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00018167702 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.59         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.82e+07      |
# |    n_updates            | 5980          |
# |    policy_gradient_loss | -0.000703     |
# |    value_loss           | 5.72e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 22.3          |
# |    ep_rew_mean          | -1.7e+04      |
# | time/                   |               |
# |    fps                  | 390           |
# |    iterations           | 14            |
# |    time_elapsed         | 73            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00028361104 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.59         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.59e+07      |
# |    n_updates            | 5990          |
# |    policy_gradient_loss | -0.00101      |
# |    value_loss           | 5.08e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.1         |
# |    ep_rew_mean          | -1.78e+04    |
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 15           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0001914732 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.54e+07     |
# |    n_updates            | 6000         |
# |    policy_gradient_loss | -0.000621    |
# |    value_loss           | 4.42e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.9          |
# |    ep_rew_mean          | -1.94e+04     |
# | time/                   |               |
# |    fps                  | 388           |
# |    iterations           | 16            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00011208482 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.59         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.35e+07      |
# |    n_updates            | 6010          |
# |    policy_gradient_loss | -0.000575     |
# |    value_loss           | 4.75e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25           |
# |    ep_rew_mean          | -1.94e+04    |
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 17           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 7.946527e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.29e+07     |
# |    n_updates            | 6020         |
# |    policy_gradient_loss | -0.000288    |
# |    value_loss           | 5.05e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 23.3          |
# |    ep_rew_mean          | -1.78e+04     |
# | time/                   |               |
# |    fps                  | 387           |
# |    iterations           | 18            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00010081101 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.59         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.51e+07      |
# |    n_updates            | 6030          |
# |    policy_gradient_loss | -0.000491     |
# |    value_loss           | 5.18e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.1          |
# |    ep_rew_mean          | -1.93e+04     |
# | time/                   |               |
# |    fps                  | 386           |
# |    iterations           | 19            |
# |    time_elapsed         | 100           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00024839398 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.58         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.98e+07      |
# |    n_updates            | 6040          |
# |    policy_gradient_loss | -0.000861     |
# |    value_loss           | 4.43e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.5          |
# |    ep_rew_mean          | -2.13e+04     |
# | time/                   |               |
# |    fps                  | 386           |
# |    iterations           | 20            |
# |    time_elapsed         | 106           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00029341952 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.58         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.39e+07      |
# |    n_updates            | 6050          |
# |    policy_gradient_loss | -0.0011       |
# |    value_loss           | 5.36e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.1          |
# |    ep_rew_mean          | -1.99e+04     |
# | time/                   |               |
# |    fps                  | 385           |
# |    iterations           | 21            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00030115288 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.58         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.53e+07      |
# |    n_updates            | 6060          |
# |    policy_gradient_loss | -0.000876     |
# |    value_loss           | 5.82e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 22.3          |
# |    ep_rew_mean          | -1.72e+04     |
# | time/                   |               |
# |    fps                  | 385           |
# |    iterations           | 22            |
# |    time_elapsed         | 116           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00010129073 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.56         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.92e+07      |
# |    n_updates            | 6070          |
# |    policy_gradient_loss | -0.000382     |
# |    value_loss           | 5.3e+07       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.1         |
# |    ep_rew_mean          | -1.96e+04    |
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 23           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0003216382 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.56        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63e+07     |
# |    n_updates            | 6080         |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 4.47e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.9          |
# |    ep_rew_mean          | -2.11e+04     |
# | time/                   |               |
# |    fps                  | 384           |
# |    iterations           | 24            |
# |    time_elapsed         | 127           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00011453379 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.57         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.64e+07      |
# |    n_updates            | 6090          |
# |    policy_gradient_loss | -0.000556     |
# |    value_loss           | 5.05e+07      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 28.5           |
# |    ep_rew_mean          | -2.25e+04      |
# | time/                   |                |
# |    fps                  | 384            |
# |    iterations           | 25             |
# |    time_elapsed         | 133            |
# |    total_timesteps      | 51200          |
# | train/                  |                |
# |    approx_kl            | 0.000111832924 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -4.57          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.32e+07       |
# |    n_updates            | 6100           |
# |    policy_gradient_loss | -0.000713      |
# |    value_loss           | 6.01e+07       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.3         |
# |    ep_rew_mean          | -2.04e+04    |
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 26           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 9.291188e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.57        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3e+07        |
# |    n_updates            | 6110         |
# |    policy_gradient_loss | -0.000374    |
# |    value_loss           | 5.62e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 29.1          |
# |    ep_rew_mean          | -2.29e+04     |
# | time/                   |               |
# |    fps                  | 383           |
# |    iterations           | 27            |
# |    time_elapsed         | 144           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00020359777 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.57         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.29e+07      |
# |    n_updates            | 6120          |
# |    policy_gradient_loss | -0.00103      |
# |    value_loss           | 5.94e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26           |
# |    ep_rew_mean          | -2.06e+04    |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 28           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 5.463985e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.58        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.77e+07     |
# |    n_updates            | 6130         |
# |    policy_gradient_loss | -0.000301    |
# |    value_loss           | 5.94e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.4          |
# |    ep_rew_mean          | -1.92e+04     |
# | time/                   |               |
# |    fps                  | 383           |
# |    iterations           | 29            |
# |    time_elapsed         | 155           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00038036748 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.56         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.55e+07      |
# |    n_updates            | 6140          |
# |    policy_gradient_loss | -0.00122      |
# |    value_loss           | 5.56e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.4          |
# |    ep_rew_mean          | -2.05e+04     |
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 30            |
# |    time_elapsed         | 160           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00023989083 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.55         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.6e+07       |
# |    n_updates            | 6150          |
# |    policy_gradient_loss | -0.000636     |
# |    value_loss           | 5.34e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.7          |
# |    ep_rew_mean          | -2.08e+04     |
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 31            |
# |    time_elapsed         | 165           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00041548233 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.52         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.18e+07      |
# |    n_updates            | 6160          |
# |    policy_gradient_loss | -0.00111      |
# |    value_loss           | 5.59e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.8         |
# |    ep_rew_mean          | -1.92e+04    |
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 32           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 7.368796e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.52        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.8e+07      |
# |    n_updates            | 6170         |
# |    policy_gradient_loss | -0.000354    |
# |    value_loss           | 5.72e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.1          |
# |    ep_rew_mean          | -1.96e+04     |
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 33            |
# |    time_elapsed         | 176           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00026091738 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.51         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.57e+07      |
# |    n_updates            | 6180          |
# |    policy_gradient_loss | -0.000845     |
# |    value_loss           | 4.86e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.4          |
# |    ep_rew_mean          | -1.96e+04     |
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 34            |
# |    time_elapsed         | 182           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00034358483 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.51         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.49e+07      |
# |    n_updates            | 6190          |
# |    policy_gradient_loss | -0.00111      |
# |    value_loss           | 4.86e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.6          |
# |    ep_rew_mean          | -2.06e+04     |
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 35            |
# |    time_elapsed         | 187           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00026325395 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.51         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.83e+07      |
# |    n_updates            | 6200          |
# |    policy_gradient_loss | -0.00087      |
# |    value_loss           | 5.31e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.6          |
# |    ep_rew_mean          | -1.98e+04     |
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 36            |
# |    time_elapsed         | 193           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.00031389724 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.5          |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.13e+07      |
# |    n_updates            | 6210          |
# |    policy_gradient_loss | -0.00112      |
# |    value_loss           | 5.87e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.8          |
# |    ep_rew_mean          | -1.92e+04     |
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 37            |
# |    time_elapsed         | 198           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00017626645 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.49         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.16e+07      |
# |    n_updates            | 6220          |
# |    policy_gradient_loss | -0.000599     |
# |    value_loss           | 5.06e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.4          |
# |    ep_rew_mean          | -2.17e+04     |
# | time/                   |               |
# |    fps                  | 380           |
# |    iterations           | 38            |
# |    time_elapsed         | 204           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 3.0374911e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.48         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.28e+07      |
# |    n_updates            | 6230          |
# |    policy_gradient_loss | -8.72e-05     |
# |    value_loss           | 4.94e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 27.7          |
# |    ep_rew_mean          | -2.19e+04     |
# | time/                   |               |
# |    fps                  | 380           |
# |    iterations           | 39            |
# |    time_elapsed         | 209           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00012267788 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.48         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.94e+07      |
# |    n_updates            | 6240          |
# |    policy_gradient_loss | -0.000575     |
# |    value_loss           | 5.73e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.9          |
# |    ep_rew_mean          | -2.02e+04     |
# | time/                   |               |
# |    fps                  | 380           |
# |    iterations           | 40            |
# |    time_elapsed         | 215           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 6.1610684e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.48         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.14e+07      |
# |    n_updates            | 6250          |
# |    policy_gradient_loss | -0.00033      |
# |    value_loss           | 6.26e+07      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 28.7           |
# |    ep_rew_mean          | -2.26e+04      |
# | time/                   |                |
# |    fps                  | 380            |
# |    iterations           | 41             |
# |    time_elapsed         | 220            |
# |    total_timesteps      | 83968          |
# | train/                  |                |
# |    approx_kl            | 0.000100523845 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -4.48          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.72e+07       |
# |    n_updates            | 6260           |
# |    policy_gradient_loss | -0.000342      |
# |    value_loss           | 5.42e+07       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.7          |
# |    ep_rew_mean          | -1.97e+04     |
# | time/                   |               |
# |    fps                  | 380           |
# |    iterations           | 42            |
# |    time_elapsed         | 226           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00024015663 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.48         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.56e+07      |
# |    n_updates            | 6270          |
# |    policy_gradient_loss | -0.00106      |
# |    value_loss           | 5.78e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.6         |
# |    ep_rew_mean          | -2.02e+04    |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 43           |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 5.795568e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.49        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.96e+07     |
# |    n_updates            | 6280         |
# |    policy_gradient_loss | -0.000272    |
# |    value_loss           | 5.11e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.1          |
# |    ep_rew_mean          | -2.09e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 44            |
# |    time_elapsed         | 237           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00019587722 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.48         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.96e+07      |
# |    n_updates            | 6290          |
# |    policy_gradient_loss | -0.000585     |
# |    value_loss           | 5.08e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 22.1          |
# |    ep_rew_mean          | -1.71e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 45            |
# |    time_elapsed         | 242           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00012190401 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.47         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.16e+07      |
# |    n_updates            | 6300          |
# |    policy_gradient_loss | -0.000623     |
# |    value_loss           | 5.65e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.4         |
# |    ep_rew_mean          | -1.84e+04    |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 46           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0002902601 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.56e+07     |
# |    n_updates            | 6310         |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 5.07e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 23.9          |
# |    ep_rew_mean          | -1.86e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 47            |
# |    time_elapsed         | 253           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00027354155 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.48         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.04e+07      |
# |    n_updates            | 6320          |
# |    policy_gradient_loss | -0.00108      |
# |    value_loss           | 4.94e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.7          |
# |    ep_rew_mean          | -2.1e+04      |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 48            |
# |    time_elapsed         | 259           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00016327543 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.49         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.64e+07      |
# |    n_updates            | 6330          |
# |    policy_gradient_loss | -0.000623     |
# |    value_loss           | 4.96e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 22.7          |
# |    ep_rew_mean          | -1.73e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 49            |
# |    time_elapsed         | 264           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 8.1109785e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.49         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.71e+07      |
# |    n_updates            | 6340          |
# |    policy_gradient_loss | -0.000393     |
# |    value_loss           | 5.65e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.9          |
# |    ep_rew_mean          | -1.93e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 50            |
# |    time_elapsed         | 269           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 0.00035691817 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.49         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.75e+07      |
# |    n_updates            | 6350          |
# |    policy_gradient_loss | -0.00104      |
# |    value_loss           | 4.22e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.2          |
# |    ep_rew_mean          | -2.04e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 51            |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00021375885 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.5          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.29e+07      |
# |    n_updates            | 6360          |
# |    policy_gradient_loss | -0.000751     |
# |    value_loss           | 4.85e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 26.4          |
# |    ep_rew_mean          | -2.07e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 52            |
# |    time_elapsed         | 280           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 0.00023852257 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.52         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.09e+07      |
# |    n_updates            | 6370          |
# |    policy_gradient_loss | -0.000684     |
# |    value_loss           | 5.78e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.2          |
# |    ep_rew_mean          | -1.96e+04     |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 53            |
# |    time_elapsed         | 286           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 0.00010712494 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# ...
# |    time_elapsed         | 3094         |
# |    total_timesteps      | 1165312      |
# | train/                  |              |
# |    approx_kl            | 0.0025157428 |
# |    clip_fraction        | 0.002        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e+07     |
# |    n_updates            | 11540        |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 2.45e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.7         |
# |    ep_rew_mean          | -1.16e+04    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 570          |
# |    time_elapsed         | 3099         |
# |    total_timesteps      | 1167360      |
# | train/                  |              |
# |    approx_kl            | 0.0087234825 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+07     |
# |    n_updates            | 11550        |
# |    policy_gradient_loss | -0.00442     |
# |    value_loss           | 2.13e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.8         |
# |    ep_rew_mean          | -1.06e+04    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 571          |
# |    time_elapsed         | 3105         |
# |    total_timesteps      | 1169408      |
# | train/                  |              |
# |    approx_kl            | 0.0047821337 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.1e+06      |
# |    n_updates            | 11560        |
# |    policy_gradient_loss | -0.00442     |
# |    value_loss           | 1.96e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13          |
# |    ep_rew_mean          | -1.04e+04   |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 572         |
# |    time_elapsed         | 3110        |
# |    total_timesteps      | 1171456     |
# | train/                  |             |
# |    approx_kl            | 0.003069418 |
# |    clip_fraction        | 0.00908     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.817      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.59e+06    |
# |    n_updates            | 11570       |
# |    policy_gradient_loss | -0.00264    |
# |    value_loss           | 1.68e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.2         |
# |    ep_rew_mean          | -1.02e+04    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 573          |
# |    time_elapsed         | 3116         |
# |    total_timesteps      | 1173504      |
# | train/                  |              |
# |    approx_kl            | 0.0050948095 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.678       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.27e+06     |
# |    n_updates            | 11580        |
# |    policy_gradient_loss | -0.00627     |
# |    value_loss           | 1.84e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.9         |
# |    ep_rew_mean          | -9.18e+03    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 574          |
# |    time_elapsed         | 3122         |
# |    total_timesteps      | 1175552      |
# | train/                  |              |
# |    approx_kl            | 0.0016631705 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.601       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.43e+06     |
# |    n_updates            | 11590        |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 1.58e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.8        |
# |    ep_rew_mean          | -1.06e+04   |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 575         |
# |    time_elapsed         | 3127        |
# |    total_timesteps      | 1177600     |
# | train/                  |             |
# |    approx_kl            | 0.014060896 |
# |    clip_fraction        | 0.0717      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.16e+06    |
# |    n_updates            | 11600       |
# |    policy_gradient_loss | 0.00348     |
# |    value_loss           | 1.61e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.1         |
# |    ep_rew_mean          | -9.47e+03    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 576          |
# |    time_elapsed         | 3133         |
# |    total_timesteps      | 1179648      |
# | train/                  |              |
# |    approx_kl            | 0.0009917677 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.64e+06     |
# |    n_updates            | 11610        |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 1.63e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.2         |
# |    ep_rew_mean          | -1.03e+04    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 577          |
# |    time_elapsed         | 3138         |
# |    total_timesteps      | 1181696      |
# | train/                  |              |
# |    approx_kl            | 0.0024645221 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.559       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.59e+06     |
# |    n_updates            | 11620        |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 1.58e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.6         |
# |    ep_rew_mean          | -9.12e+03    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 578          |
# |    time_elapsed         | 3144         |
# |    total_timesteps      | 1183744      |
# | train/                  |              |
# |    approx_kl            | 0.0017606087 |
# |    clip_fraction        | 0.00854      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.487       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.69e+06     |
# |    n_updates            | 11630        |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 1.59e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.1         |
# |    ep_rew_mean          | -1.01e+04    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 579          |
# |    time_elapsed         | 3149         |
# |    total_timesteps      | 1185792      |
# | train/                  |              |
# |    approx_kl            | 0.0020594993 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.408       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.73e+06     |
# |    n_updates            | 11640        |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 1.46e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.7         |
# |    ep_rew_mean          | -9.81e+03    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 580          |
# |    time_elapsed         | 3154         |
# |    total_timesteps      | 1187840      |
# | train/                  |              |
# |    approx_kl            | 0.0010055922 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.349       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.55e+06     |
# |    n_updates            | 11650        |
# |    policy_gradient_loss | -0.000809    |
# |    value_loss           | 1.44e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.5         |
# |    ep_rew_mean          | -8.61e+03    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 581          |
# |    time_elapsed         | 3160         |
# |    total_timesteps      | 1189888      |
# | train/                  |              |
# |    approx_kl            | 0.0031457234 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.319       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.53e+06     |
# |    n_updates            | 11660        |
# |    policy_gradient_loss | -0.00058     |
# |    value_loss           | 1.53e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.4         |
# |    ep_rew_mean          | -7.94e+03    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 582          |
# |    time_elapsed         | 3166         |
# |    total_timesteps      | 1191936      |
# | train/                  |              |
# |    approx_kl            | 0.0052487385 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.204       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.09e+06     |
# |    n_updates            | 11670        |
# |    policy_gradient_loss | 0.000322     |
# |    value_loss           | 1.48e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.1         |
# |    ep_rew_mean          | -1.01e+04    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 583          |
# |    time_elapsed         | 3171         |
# |    total_timesteps      | 1193984      |
# | train/                  |              |
# |    approx_kl            | 0.0059499713 |
# |    clip_fraction        | 0.00767      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.197       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.23e+06     |
# |    n_updates            | 11680        |
# |    policy_gradient_loss | -0.000512    |
# |    value_loss           | 1.34e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 12.2          |
# |    ep_rew_mean          | -9.65e+03     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 584           |
# |    time_elapsed         | 3177          |
# |    total_timesteps      | 1196032       |
# | train/                  |               |
# |    approx_kl            | 0.00018482294 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.407        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.8e+06       |
# |    n_updates            | 11690         |
# |    policy_gradient_loss | 0.000269      |
# |    value_loss           | 1.45e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 13.4          |
# |    ep_rew_mean          | -1.04e+04     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 585           |
# |    time_elapsed         | 3182          |
# |    total_timesteps      | 1198080       |
# | train/                  |               |
# |    approx_kl            | 5.0799863e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.39         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.46e+06      |
# |    n_updates            | 11700         |
# |    policy_gradient_loss | -0.000305     |
# |    value_loss           | 1.58e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 11.5          |
# |    ep_rew_mean          | -8.81e+03     |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 586           |
# |    time_elapsed         | 3188          |
# |    total_timesteps      | 1200128       |
# | train/                  |               |
# |    approx_kl            | 0.00013674155 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.375        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.28e+06      |
# |    n_updates            | 11710         |
# |    policy_gradient_loss | -0.00068      |
# |    value_loss           | 1.48e+07      |
# -------------------------------------------

# %% [markdown]
# # Save Model

# %% [markdown]
# # Evaluate Model

# %%
scenarioEnv = DeterministicScenarioEnvironment(13, 19, 21, 4, 2, 2, 2, 0, 0)
sampleEnvObs = scenarioEnv.reset()
done = False
score = 0 

while not done:
    action, _ = model.predict(sampleEnvObs)
    sampleEnvObs, reward, done, info = scenarioEnv.step(action)
    score+=reward
    print('Score:{} Action:{} State:{}'.format(score, action, [sampleEnvObs["missiles"],sampleEnvObs["expectedShipDamage"], sampleEnvObs["currentShipDamage"], sampleEnvObs["assets"]]))
scenarioEnv.close()
# Out:
# Score:-360 Action:[5 4 1 1] State:[9, array([4, 2, 2, 2, 0, 0]), array([0, 0, 0, 0, 2, 2]), array([18, 20])]
# Score:-1120 Action:[5 4 1 1] State:[5, array([4, 2, 2, 2, 0, 0]), array([0, 0, 0, 0, 4, 4]), array([16, 18])]
# Score:-1880 Action:[5 4 1 1] State:[1, array([4, 2, 2, 2, 0, 0]), array([0, 0, 0, 0, 6, 6]), array([14, 16])]
# Score:-4640 Action:[5 4 1 1] State:[-3, array([4, 2, 2, 2, 0, 0]), array([0, 0, 0, 0, 8, 8]), array([13, 15])]
